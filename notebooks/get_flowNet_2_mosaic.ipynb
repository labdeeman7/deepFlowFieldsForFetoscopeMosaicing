# %% [markdown]
# ##Get data

# %%
# Import PyDrive and associated libraries.
# This only needs to be done once per notebook.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# List .txt files in the root.
#
# Search query reference:
# https://developers.google.com/drive/v2/web/search-parameters
listed = drive.ListFile({'q': "title contains 'flow_files_anon002_full.zip'"}).GetList()
for flow_file in listed:
  print('title {}, id {}'.format(flow_file['title'], flow_file['id']))

listed = drive.ListFile({'q': "title contains 'masks.zip'"}).GetList()
for mask_file in listed:
  print('title {}, id {}'.format(mask_file['title'], mask_file['id']))

listed = drive.ListFile({'q': "title contains 'anon002.zip'"}).GetList()
for video_file in listed:
  print('title {}, id {}'.format(video_file['title'], video_file['id']))
# Out:
# title flow_files_anon002_full.zip, id 1w1T69EEq_MvQUp5ju0_hbSLcsckeUDgN
# title masks.zip, id 1JyhSp96W7cPy37UGugT8AXPeIjC6TMSI
# title anon002.zip, id 1gc1LHkTElF1BNB5OfRjOczuvJHEAqWG8

# %%
# Import PyDrive and associated libraries.
# This only needs to be done once per notebook.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import os

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)


file_id = flow_file['id']

fname = os.path.join('/content', 'flow_files.zip')
print('downloading to {}'.format(fname))
f_ = drive.CreateFile({'id': file_id})
f_.GetContentFile(fname)


file_id = mask_file['id']

fname = os.path.join('/content', 'masks.zip')
print('downloading to {}'.format(fname))
f_ = drive.CreateFile({'id': file_id})
f_.GetContentFile(fname)


file_id = video_file['id']

fname = os.path.join('/content', 'video.zip')
print('downloading to {}'.format(fname))
f_ = drive.CreateFile({'id': file_id})
f_.GetContentFile(fname)
# Out:
# downloading to /content/flow_files.zip
# downloading to /content/masks.zip
# downloading to /content/video.zip

# %%
# !unzip flow_files.zip
# !unzip masks.zip
# !unzip video.zip
# Out:
# Archive:  flow_files.zip
#    creating: flow_files_anon002_full/
#   inflating: flow_files_anon002_full/000000.flo
#   inflating: flow_files_anon002_full/000001.flo
#   inflating: flow_files_anon002_full/000002.flo
#   inflating: flow_files_anon002_full/000003.flo
#   inflating: flow_files_anon002_full/000004.flo
#   inflating: flow_files_anon002_full/000005.flo
#   inflating: flow_files_anon002_full/000006.flo
#   inflating: flow_files_anon002_full/000007.flo
#   inflating: flow_files_anon002_full/000008.flo
#   inflating: flow_files_anon002_full/000009.flo
#   inflating: flow_files_anon002_full/000010.flo
#   inflating: flow_files_anon002_full/000011.flo
#   inflating: flow_files_anon002_full/000012.flo
#   inflating: flow_files_anon002_full/000013.flo
#   inflating: flow_files_anon002_full/000014.flo
#   inflating: flow_files_anon002_full/000015.flo
#   inflating: flow_files_anon002_full/000016.flo
#   inflating: flow_files_anon002_full/000017.flo
#   inflating: flow_files_anon002_full/000018.flo
#   inflating: flow_files_anon002_full/000019.flo
#   inflating: flow_files_anon002_full/000020.flo
#   inflating: flow_files_anon002_full/000021.flo
#   inflating: flow_files_anon002_full/000022.flo
#   inflating: flow_files_anon002_full/000023.flo
#   inflating: flow_files_anon002_full/000024.flo
#   inflating: flow_files_anon002_full/000025.flo
#   inflating: flow_files_anon002_full/000026.flo
#   inflating: flow_files_anon002_full/000027.flo
#   inflating: flow_files_anon002_full/000028.flo
#   inflating: flow_files_anon002_full/000029.flo
#   inflating: flow_files_anon002_full/000030.flo
#   inflating: flow_files_anon002_full/000031.flo
#   inflating: flow_files_anon002_full/000032.flo
#   inflating: flow_files_anon002_full/000033.flo
#   inflating: flow_files_anon002_full/000034.flo
#   inflating: flow_files_anon002_full/000035.flo
#   inflating: flow_files_anon002_full/000036.flo
#   inflating: flow_files_anon002_full/000037.flo
#   inflating: flow_files_anon002_full/000038.flo
#   inflating: flow_files_anon002_full/000039.flo
#   inflating: flow_files_anon002_full/000040.flo
#   inflating: flow_files_anon002_full/000041.flo
#   inflating: flow_files_anon002_full/000042.flo
#   inflating: flow_files_anon002_full/000043.flo
#   inflating: flow_files_anon002_full/000044.flo
#   inflating: flow_files_anon002_full/000045.flo
#   inflating: flow_files_anon002_full/000046.flo
#   inflating: flow_files_anon002_full/000047.flo
#   inflating: flow_files_anon002_full/000048.flo
#   inflating: flow_files_anon002_full/000049.flo
#   inflating: flow_files_anon002_full/000050.flo
#   inflating: flow_files_anon002_full/000051.flo
#   inflating: flow_files_anon002_full/000052.flo
#   inflating: flow_files_anon002_full/000053.flo
#   inflating: flow_files_anon002_full/000054.flo
#   inflating: flow_files_anon002_full/000055.flo
#   inflating: flow_files_anon002_full/000056.flo
#   inflating: flow_files_anon002_full/000057.flo
#   inflating: flow_files_anon002_full/000058.flo
#   inflating: flow_files_anon002_full/000059.flo
#   inflating: flow_files_anon002_full/000060.flo
#   inflating: flow_files_anon002_full/000061.flo
#   inflating: flow_files_anon002_full/000062.flo
#   inflating: flow_files_anon002_full/000063.flo
#   inflating: flow_files_anon002_full/000064.flo
#   inflating: flow_files_anon002_full/000065.flo
#   inflating: flow_files_anon002_full/000066.flo
#   inflating: flow_files_anon002_full/000067.flo
#   inflating: flow_files_anon002_full/000068.flo
#   inflating: flow_files_anon002_full/000069.flo
#   inflating: flow_files_anon002_full/000070.flo
#   inflating: flow_files_anon002_full/000071.flo
#   inflating: flow_files_anon002_full/000072.flo
#   inflating: flow_files_anon002_full/000073.flo
#   inflating: flow_files_anon002_full/000074.flo
#   inflating: flow_files_anon002_full/000075.flo
#   inflating: flow_files_anon002_full/000076.flo
#   inflating: flow_files_anon002_full/000077.flo
#   inflating: flow_files_anon002_full/000078.flo
#   inflating: flow_files_anon002_full/000079.flo
#   inflating: flow_files_anon002_full/000080.flo
#   inflating: flow_files_anon002_full/000081.flo
#   inflating: flow_files_anon002_full/000082.flo
#   inflating: flow_files_anon002_full/000083.flo
#   inflating: flow_files_anon002_full/000084.flo
#   inflating: flow_files_anon002_full/000085.flo
#   inflating: flow_files_anon002_full/000086.flo
#   inflating: flow_files_anon002_full/000087.flo
#   inflating: flow_files_anon002_full/000088.flo
#   inflating: flow_files_anon002_full/000089.flo
#   inflating: flow_files_anon002_full/000090.flo
#   inflating: flow_files_anon002_full/000091.flo
#   inflating: flow_files_anon002_full/000092.flo
#   inflating: flow_files_anon002_full/000093.flo
#   inflating: flow_files_anon002_full/000094.flo
#   inflating: flow_files_anon002_full/000095.flo
#   inflating: flow_files_anon002_full/000096.flo
#   inflating: flow_files_anon002_full/000097.flo
#   inflating: flow_files_anon002_full/000098.flo
#   inflating: flow_files_anon002_full/000099.flo
#   inflating: flow_files_anon002_full/000100.flo
#   inflating: flow_files_anon002_full/000101.flo
#   inflating: flow_files_anon002_full/000102.flo
#   inflating: flow_files_anon002_full/000103.flo
#   inflating: flow_files_anon002_full/000104.flo
#   inflating: flow_files_anon002_full/000105.flo
#   inflating: flow_files_anon002_full/000106.flo
#   inflating: flow_files_anon002_full/000107.flo
#   inflating: flow_files_anon002_full/000108.flo
#   inflating: flow_files_anon002_full/000109.flo
#   inflating: flow_files_anon002_full/000110.flo
#   inflating: flow_files_anon002_full/000111.flo
#   inflating: flow_files_anon002_full/000112.flo
#   inflating: flow_files_anon002_full/000113.flo
#   inflating: flow_files_anon002_full/000114.flo
#   inflating: flow_files_anon002_full/000115.flo
#   inflating: flow_files_anon002_full/000116.flo
#   inflating: flow_files_anon002_full/000117.flo
#   inflating: flow_files_anon002_full/000118.flo
#   inflating: flow_files_anon002_full/000119.flo
#   inflating: flow_files_anon002_full/000120.flo
#   inflating: flow_files_anon002_full/000121.flo
#   inflating: flow_files_anon002_full/000122.flo
#   inflating: flow_files_anon002_full/000123.flo
#   inflating: flow_files_anon002_full/000124.flo
#   inflating: flow_files_anon002_full/000125.flo
#   inflating: flow_files_anon002_full/000126.flo
#   inflating: flow_files_anon002_full/000127.flo
#   inflating: flow_files_anon002_full/000128.flo
#   inflating: flow_files_anon002_full/000129.flo
#   inflating: flow_files_anon002_full/000130.flo
#   inflating: flow_files_anon002_full/000131.flo
#   inflating: flow_files_anon002_full/000132.flo
#   inflating: flow_files_anon002_full/000133.flo
#   inflating: flow_files_anon002_full/000134.flo
#   inflating: flow_files_anon002_full/000135.flo
#   inflating: flow_files_anon002_full/000136.flo
#   inflating: flow_files_anon002_full/000137.flo
#   inflating: flow_files_anon002_full/000138.flo
#   inflating: flow_files_anon002_full/000139.flo
#   inflating: flow_files_anon002_full/000140.flo
#   inflating: flow_files_anon002_full/000141.flo
#   inflating: flow_files_anon002_full/000142.flo
#   inflating: flow_files_anon002_full/000143.flo
#   inflating: flow_files_anon002_full/000144.flo
#   inflating: flow_files_anon002_full/000145.flo
#   inflating: flow_files_anon002_full/000146.flo
#   inflating: flow_files_anon002_full/000147.flo
#   inflating: flow_files_anon002_full/000148.flo
#   inflating: flow_files_anon002_full/000149.flo
#   inflating: flow_files_anon002_full/000150.flo
#   inflating: flow_files_anon002_full/000151.flo
#   inflating: flow_files_anon002_full/000152.flo
#   inflating: flow_files_anon002_full/000153.flo
#   inflating: flow_files_anon002_full/000154.flo
#   inflating: flow_files_anon002_full/000155.flo
#   inflating: flow_files_anon002_full/000156.flo
#   inflating: flow_files_anon002_full/000157.flo
#   inflating: flow_files_anon002_full/000158.flo
#   inflating: flow_files_anon002_full/000159.flo
#   inflating: flow_files_anon002_full/000160.flo
#   inflating: flow_files_anon002_full/000161.flo
#   inflating: flow_files_anon002_full/000162.flo
#   inflating: flow_files_anon002_full/000163.flo
#   inflating: flow_files_anon002_full/000164.flo
#   inflating: flow_files_anon002_full/000165.flo
#   inflating: flow_files_anon002_full/000166.flo
#   inflating: flow_files_anon002_full/000167.flo
#   inflating: flow_files_anon002_full/000168.flo
#   inflating: flow_files_anon002_full/000169.flo
#   inflating: flow_files_anon002_full/000170.flo
#   inflating: flow_files_anon002_full/000171.flo
#   inflating: flow_files_anon002_full/000172.flo
#   inflating: flow_files_anon002_full/000173.flo
#   inflating: flow_files_anon002_full/000174.flo
#   inflating: flow_files_anon002_full/000175.flo
#   inflating: flow_files_anon002_full/000176.flo
#   inflating: flow_files_anon002_full/000177.flo
#   inflating: flow_files_anon002_full/000178.flo
#   inflating: flow_files_anon002_full/000179.flo
#   inflating: flow_files_anon002_full/000180.flo
#   inflating: flow_files_anon002_full/000181.flo
#   inflating: flow_files_anon002_full/000182.flo
#   inflating: flow_files_anon002_full/000183.flo
#   inflating: flow_files_anon002_full/000184.flo
#   inflating: flow_files_anon002_full/000185.flo
#   inflating: flow_files_anon002_full/000186.flo
#   inflating: flow_files_anon002_full/000187.flo
#   inflating: flow_files_anon002_full/000188.flo
#   inflating: flow_files_anon002_full/000189.flo
#   inflating: flow_files_anon002_full/000190.flo
#   inflating: flow_files_anon002_full/000191.flo
#   inflating: flow_files_anon002_full/000192.flo
#   inflating: flow_files_anon002_full/000193.flo
#   inflating: flow_files_anon002_full/000194.flo
#   inflating: flow_files_anon002_full/000195.flo
#   inflating: flow_files_anon002_full/000196.flo
#   inflating: flow_files_anon002_full/000197.flo
#   inflating: flow_files_anon002_full/000198.flo
#   inflating: flow_files_anon002_full/000199.flo
#   inflating: flow_files_anon002_full/000200.flo
#   inflating: flow_files_anon002_full/000201.flo
#   inflating: flow_files_anon002_full/000202.flo
#   inflating: flow_files_anon002_full/000203.flo
#   inflating: flow_files_anon002_full/000204.flo
#   inflating: flow_files_anon002_full/000205.flo
#   inflating: flow_files_anon002_full/000206.flo
#   inflating: flow_files_anon002_full/000207.flo
#   inflating: flow_files_anon002_full/000208.flo
#   inflating: flow_files_anon002_full/000209.flo
#   inflating: flow_files_anon002_full/000210.flo
#   inflating: flow_files_anon002_full/000211.flo
#   inflating: flow_files_anon002_full/000212.flo
#   inflating: flow_files_anon002_full/000213.flo
#   inflating: flow_files_anon002_full/000214.flo
#   inflating: flow_files_anon002_full/000215.flo
#   inflating: flow_files_anon002_full/000216.flo
#   inflating: flow_files_anon002_full/000217.flo
#   inflating: flow_files_anon002_full/000218.flo
#   inflating: flow_files_anon002_full/000219.flo
#   inflating: flow_files_anon002_full/000220.flo
#   inflating: flow_files_anon002_full/000221.flo
#   inflating: flow_files_anon002_full/000222.flo
#   inflating: flow_files_anon002_full/000223.flo
#   inflating: flow_files_anon002_full/000224.flo
#   inflating: flow_files_anon002_full/000225.flo
#   inflating: flow_files_anon002_full/000226.flo
#   inflating: flow_files_anon002_full/000227.flo
#   inflating: flow_files_anon002_full/000228.flo
#   inflating: flow_files_anon002_full/000229.flo
#   inflating: flow_files_anon002_full/000230.flo
#   inflating: flow_files_anon002_full/000231.flo
#   inflating: flow_files_anon002_full/000232.flo
#   inflating: flow_files_anon002_full/000233.flo
#   inflating: flow_files_anon002_full/000234.flo
#   inflating: flow_files_anon002_full/000235.flo
#   inflating: flow_files_anon002_full/000236.flo
#   inflating: flow_files_anon002_full/000237.flo
#   inflating: flow_files_anon002_full/000238.flo
#   inflating: flow_files_anon002_full/000239.flo
#   inflating: flow_files_anon002_full/000240.flo
#   inflating: flow_files_anon002_full/000241.flo
#   inflating: flow_files_anon002_full/000242.flo
#   inflating: flow_files_anon002_full/000243.flo
#   inflating: flow_files_anon002_full/000244.flo
#   inflating: flow_files_anon002_full/000245.flo
#   inflating: flow_files_anon002_full/000246.flo
#   inflating: flow_files_anon002_full/000247.flo
#   inflating: flow_files_anon002_full/000248.flo
#   inflating: flow_files_anon002_full/000249.flo
#   inflating: flow_files_anon002_full/000250.flo
#   inflating: flow_files_anon002_full/000251.flo
#   inflating: flow_files_anon002_full/000252.flo
#   inflating: flow_files_anon002_full/000253.flo
#   inflating: flow_files_anon002_full/000254.flo
#   inflating: flow_files_anon002_full/000255.flo
#   inflating: flow_files_anon002_full/000256.flo
#   inflating: flow_files_anon002_full/000257.flo
#   inflating: flow_files_anon002_full/000258.flo
#   inflating: flow_files_anon002_full/000259.flo
#   inflating: flow_files_anon002_full/000260.flo
#   inflating: flow_files_anon002_full/000261.flo
#   inflating: flow_files_anon002_full/000262.flo
#   inflating: flow_files_anon002_full/000263.flo
#   inflating: flow_files_anon002_full/000264.flo
#   inflating: flow_files_anon002_full/000265.flo
#   inflating: flow_files_anon002_full/000266.flo
#   inflating: flow_files_anon002_full/000267.flo
#   inflating: flow_files_anon002_full/000268.flo
#   inflating: flow_files_anon002_full/000269.flo
#   inflating: flow_files_anon002_full/000270.flo
#   inflating: flow_files_anon002_full/000271.flo
#   inflating: flow_files_anon002_full/000272.flo
#   inflating: flow_files_anon002_full/000273.flo
#   inflating: flow_files_anon002_full/000274.flo
#   inflating: flow_files_anon002_full/000275.flo
#   inflating: flow_files_anon002_full/000276.flo
#   inflating: flow_files_anon002_full/000277.flo
#   inflating: flow_files_anon002_full/000278.flo
#   inflating: flow_files_anon002_full/000279.flo
#   inflating: flow_files_anon002_full/000280.flo
#   inflating: flow_files_anon002_full/000281.flo
#   inflating: flow_files_anon002_full/000282.flo
#   inflating: flow_files_anon002_full/000283.flo
#   inflating: flow_files_anon002_full/000284.flo
#   inflating: flow_files_anon002_full/000285.flo
#   inflating: flow_files_anon002_full/000286.flo
#   inflating: flow_files_anon002_full/000287.flo
#   inflating: flow_files_anon002_full/000288.flo
#   inflating: flow_files_anon002_full/000289.flo
#   inflating: flow_files_anon002_full/000290.flo
#   inflating: flow_files_anon002_full/000291.flo
#   inflating: flow_files_anon002_full/000292.flo
#   inflating: flow_files_anon002_full/000293.flo
#   inflating: flow_files_anon002_full/000294.flo
#   inflating: flow_files_anon002_full/000295.flo
#   inflating: flow_files_anon002_full/000296.flo
#   inflating: flow_files_anon002_full/000297.flo
#   inflating: flow_files_anon002_full/000298.flo
#   inflating: flow_files_anon002_full/000299.flo
#   inflating: flow_files_anon002_full/000300.flo
#   inflating: flow_files_anon002_full/000301.flo
#   inflating: flow_files_anon002_full/000302.flo
#   inflating: flow_files_anon002_full/000303.flo
#   inflating: flow_files_anon002_full/000304.flo
#   inflating: flow_files_anon002_full/000305.flo
#   inflating: flow_files_anon002_full/000306.flo
#   inflating: flow_files_anon002_full/000307.flo
#   inflating: flow_files_anon002_full/000308.flo
#   inflating: flow_files_anon002_full/000309.flo
#   inflating: flow_files_anon002_full/000310.flo
#   inflating: flow_files_anon002_full/000311.flo
#   inflating: flow_files_anon002_full/000312.flo
#   inflating: flow_files_anon002_full/000313.flo
#   inflating: flow_files_anon002_full/000314.flo
#   inflating: flow_files_anon002_full/000315.flo
#   inflating: flow_files_anon002_full/000316.flo
#   inflating: flow_files_anon002_full/000317.flo
#   inflating: flow_files_anon002_full/000318.flo
#   inflating: flow_files_anon002_full/000319.flo
#   inflating: flow_files_anon002_full/000320.flo
#   inflating: flow_files_anon002_full/000321.flo
#   inflating: flow_files_anon002_full/000322.flo
#   inflating: flow_files_anon002_full/000323.flo
#   inflating: flow_files_anon002_full/000324.flo
#   inflating: flow_files_anon002_full/000325.flo
#   inflating: flow_files_anon002_full/000326.flo
#   inflating: flow_files_anon002_full/000327.flo
#   inflating: flow_files_anon002_full/000328.flo
#   inflating: flow_files_anon002_full/000329.flo
#   inflating: flow_files_anon002_full/000330.flo
#   inflating: flow_files_anon002_full/000331.flo
#   inflating: flow_files_anon002_full/000332.flo
#   inflating: flow_files_anon002_full/000333.flo
#   inflating: flow_files_anon002_full/000334.flo
#   inflating: flow_files_anon002_full/000335.flo
#   inflating: flow_files_anon002_full/000336.flo
#   inflating: flow_files_anon002_full/000337.flo
#   inflating: flow_files_anon002_full/000338.flo
#   inflating: flow_files_anon002_full/000339.flo
#   inflating: flow_files_anon002_full/000340.flo
#   inflating: flow_files_anon002_full/000341.flo
#   inflating: flow_files_anon002_full/000342.flo
#   inflating: flow_files_anon002_full/000343.flo
#   inflating: flow_files_anon002_full/000344.flo
#   inflating: flow_files_anon002_full/000345.flo
#   inflating: flow_files_anon002_full/000346.flo
#   inflating: flow_files_anon002_full/000347.flo
#   inflating: flow_files_anon002_full/000348.flo
#   inflating: flow_files_anon002_full/000349.flo
#   inflating: flow_files_anon002_full/000350.flo
#   inflating: flow_files_anon002_full/000351.flo
#   inflating: flow_files_anon002_full/000352.flo
#   inflating: flow_files_anon002_full/000353.flo
#   inflating: flow_files_anon002_full/000354.flo
#   inflating: flow_files_anon002_full/000355.flo
#   inflating: flow_files_anon002_full/000356.flo
#   inflating: flow_files_anon002_full/000357.flo
#   inflating: flow_files_anon002_full/000358.flo
#   inflating: flow_files_anon002_full/000359.flo
#   inflating: flow_files_anon002_full/000360.flo
#   inflating: flow_files_anon002_full/000361.flo
#   inflating: flow_files_anon002_full/000362.flo
#   inflating: flow_files_anon002_full/000363.flo
#   inflating: flow_files_anon002_full/000364.flo
#   inflating: flow_files_anon002_full/000365.flo
#   inflating: flow_files_anon002_full/000366.flo
#   inflating: flow_files_anon002_full/000367.flo
#   inflating: flow_files_anon002_full/000368.flo
#   inflating: flow_files_anon002_full/000369.flo
#   inflating: flow_files_anon002_full/000370.flo
#   inflating: flow_files_anon002_full/000371.flo
#   inflating: flow_files_anon002_full/000372.flo
#   inflating: flow_files_anon002_full/000373.flo
#   inflating: flow_files_anon002_full/000374.flo
#   inflating: flow_files_anon002_full/000375.flo
#   inflating: flow_files_anon002_full/000376.flo
#   inflating: flow_files_anon002_full/000377.flo
#   inflating: flow_files_anon002_full/000378.flo
#   inflating: flow_files_anon002_full/000379.flo
#   inflating: flow_files_anon002_full/000380.flo
#   inflating: flow_files_anon002_full/000381.flo
#   inflating: flow_files_anon002_full/000382.flo
#   inflating: flow_files_anon002_full/000383.flo
#   inflating: flow_files_anon002_full/000384.flo
#   inflating: flow_files_anon002_full/000385.flo
#   inflating: flow_files_anon002_full/000386.flo
#   inflating: flow_files_anon002_full/000387.flo
#   inflating: flow_files_anon002_full/000388.flo
#   inflating: flow_files_anon002_full/000389.flo
#   inflating: flow_files_anon002_full/000390.flo
#   inflating: flow_files_anon002_full/000391.flo
#   inflating: flow_files_anon002_full/000392.flo
#   inflating: flow_files_anon002_full/000393.flo
#   inflating: flow_files_anon002_full/000394.flo
#   inflating: flow_files_anon002_full/000395.flo
#   inflating: flow_files_anon002_full/000396.flo
#   inflating: flow_files_anon002_full/000397.flo
#   inflating: flow_files_anon002_full/000398.flo
#   inflating: flow_files_anon002_full/000399.flo
#   inflating: flow_files_anon002_full/000400.flo
#   inflating: flow_files_anon002_full/000401.flo
#   inflating: flow_files_anon002_full/000402.flo
#   inflating: flow_files_anon002_full/000403.flo
#   inflating: flow_files_anon002_full/000404.flo
#   inflating: flow_files_anon002_full/000405.flo
#   inflating: flow_files_anon002_full/000406.flo
#   inflating: flow_files_anon002_full/000407.flo
#   inflating: flow_files_anon002_full/000408.flo
#   inflating: flow_files_anon002_full/000409.flo
#   inflating: flow_files_anon002_full/000410.flo
#   inflating: flow_files_anon002_full/000411.flo
#   inflating: flow_files_anon002_full/000412.flo
#   inflating: flow_files_anon002_full/000413.flo
#   inflating: flow_files_anon002_full/000414.flo
#   inflating: flow_files_anon002_full/000415.flo
#   inflating: flow_files_anon002_full/000416.flo
#   inflating: flow_files_anon002_full/000417.flo
#   inflating: flow_files_anon002_full/000418.flo
#   inflating: flow_files_anon002_full/000419.flo
#   inflating: flow_files_anon002_full/000420.flo
#   inflating: flow_files_anon002_full/000421.flo
#   inflating: flow_files_anon002_full/000422.flo
#   inflating: flow_files_anon002_full/000423.flo
#   inflating: flow_files_anon002_full/000424.flo
#   inflating: flow_files_anon002_full/000425.flo
#   inflating: flow_files_anon002_full/000426.flo
#   inflating: flow_files_anon002_full/000427.flo
#   inflating: flow_files_anon002_full/000428.flo
#   inflating: flow_files_anon002_full/000429.flo
#   inflating: flow_files_anon002_full/000430.flo
#   inflating: flow_files_anon002_full/000431.flo
#   inflating: flow_files_anon002_full/000432.flo
#   inflating: flow_files_anon002_full/000433.flo
#   inflating: flow_files_anon002_full/000434.flo
#   inflating: flow_files_anon002_full/000435.flo
#   inflating: flow_files_anon002_full/000436.flo
#   inflating: flow_files_anon002_full/000437.flo
#   inflating: flow_files_anon002_full/000438.flo
#   inflating: flow_files_anon002_full/000439.flo
#   inflating: flow_files_anon002_full/000440.flo
#   inflating: flow_files_anon002_full/000441.flo
#   inflating: flow_files_anon002_full/000442.flo
#   inflating: flow_files_anon002_full/000443.flo
#   inflating: flow_files_anon002_full/000444.flo
#   inflating: flow_files_anon002_full/000445.flo
#   inflating: flow_files_anon002_full/000446.flo
#   inflating: flow_files_anon002_full/000447.flo
#   inflating: flow_files_anon002_full/000448.flo
#   inflating: flow_files_anon002_full/000449.flo
#   inflating: flow_files_anon002_full/000450.flo
#   inflating: flow_files_anon002_full/000451.flo
#   inflating: flow_files_anon002_full/000452.flo
#   inflating: flow_files_anon002_full/000453.flo
#   inflating: flow_files_anon002_full/000454.flo
#   inflating: flow_files_anon002_full/000455.flo
#   inflating: flow_files_anon002_full/000456.flo
#   inflating: flow_files_anon002_full/000457.flo
#   inflating: flow_files_anon002_full/000458.flo
#   inflating: flow_files_anon002_full/000459.flo
#   inflating: flow_files_anon002_full/000460.flo
#   inflating: flow_files_anon002_full/000461.flo
#   inflating: flow_files_anon002_full/000462.flo
#   inflating: flow_files_anon002_full/000463.flo
#   inflating: flow_files_anon002_full/000464.flo
#   inflating: flow_files_anon002_full/000465.flo
#   inflating: flow_files_anon002_full/000466.flo
#   inflating: flow_files_anon002_full/000467.flo
#   inflating: flow_files_anon002_full/000468.flo
#   inflating: flow_files_anon002_full/000469.flo
#   inflating: flow_files_anon002_full/000470.flo
#   inflating: flow_files_anon002_full/000471.flo
#   inflating: flow_files_anon002_full/000472.flo
#   inflating: flow_files_anon002_full/000473.flo
#   inflating: flow_files_anon002_full/000474.flo
#   inflating: flow_files_anon002_full/000475.flo
#   inflating: flow_files_anon002_full/000476.flo
#   inflating: flow_files_anon002_full/000477.flo
#   inflating: flow_files_anon002_full/000478.flo
#   inflating: flow_files_anon002_full/000479.flo
#   inflating: flow_files_anon002_full/000480.flo
#   inflating: flow_files_anon002_full/000481.flo
#   inflating: flow_files_anon002_full/000482.flo
#   inflating: flow_files_anon002_full/000483.flo
#   inflating: flow_files_anon002_full/000484.flo
#   inflating: flow_files_anon002_full/000485.flo
#   inflating: flow_files_anon002_full/000486.flo
#   inflating: flow_files_anon002_full/000487.flo
#   inflating: flow_files_anon002_full/000488.flo
#   inflating: flow_files_anon002_full/000489.flo
#   inflating: flow_files_anon002_full/000490.flo
#   inflating: flow_files_anon002_full/000491.flo
#   inflating: flow_files_anon002_full/000492.flo
#   inflating: flow_files_anon002_full/000493.flo
#   inflating: flow_files_anon002_full/000494.flo
#   inflating: flow_files_anon002_full/000495.flo
#   inflating: flow_files_anon002_full/000496.flo
#   inflating: flow_files_anon002_full/000497.flo
#   inflating: flow_files_anon002_full/000498.flo
#   inflating: flow_files_anon002_full/000499.flo
#   inflating: flow_files_anon002_full/000500.flo
#   inflating: flow_files_anon002_full/000501.flo
#   inflating: flow_files_anon002_full/000502.flo
#   inflating: flow_files_anon002_full/000503.flo
#   inflating: flow_files_anon002_full/000504.flo
#   inflating: flow_files_anon002_full/000505.flo
#   inflating: flow_files_anon002_full/000506.flo
#   inflating: flow_files_anon002_full/000507.flo
#   inflating: flow_files_anon002_full/000508.flo
#   inflating: flow_files_anon002_full/000509.flo
#   inflating: flow_files_anon002_full/000510.flo
#   inflating: flow_files_anon002_full/000511.flo
#   inflating: flow_files_anon002_full/000512.flo
#   inflating: flow_files_anon002_full/000513.flo
#   inflating: flow_files_anon002_full/000514.flo
#   inflating: flow_files_anon002_full/000515.flo
#   inflating: flow_files_anon002_full/000516.flo
#   inflating: flow_files_anon002_full/000517.flo
#   inflating: flow_files_anon002_full/000518.flo
#   inflating: flow_files_anon002_full/000519.flo
#   inflating: flow_files_anon002_full/000520.flo
#   inflating: flow_files_anon002_full/000521.flo
#   inflating: flow_files_anon002_full/000522.flo
#   inflating: flow_files_anon002_full/000523.flo
#   inflating: flow_files_anon002_full/000524.flo
#   inflating: flow_files_anon002_full/000525.flo
#   inflating: flow_files_anon002_full/000526.flo
#   inflating: flow_files_anon002_full/000527.flo
#   inflating: flow_files_anon002_full/000528.flo
#   inflating: flow_files_anon002_full/000529.flo
#   inflating: flow_files_anon002_full/000530.flo
#   inflating: flow_files_anon002_full/000531.flo
#   inflating: flow_files_anon002_full/000532.flo
#   inflating: flow_files_anon002_full/000533.flo
#   inflating: flow_files_anon002_full/000534.flo
#   inflating: flow_files_anon002_full/000535.flo
#   inflating: flow_files_anon002_full/000536.flo
#   inflating: flow_files_anon002_full/000537.flo
#   inflating: flow_files_anon002_full/000538.flo
#   inflating: flow_files_anon002_full/000539.flo
#   inflating: flow_files_anon002_full/000540.flo
#   inflating: flow_files_anon002_full/000541.flo
#   inflating: flow_files_anon002_full/000542.flo
#   inflating: flow_files_anon002_full/000543.flo
#   inflating: flow_files_anon002_full/000544.flo
#   inflating: flow_files_anon002_full/000545.flo
#   inflating: flow_files_anon002_full/000546.flo
#   inflating: flow_files_anon002_full/000547.flo
#   inflating: flow_files_anon002_full/000548.flo
#   inflating: flow_files_anon002_full/000549.flo
#   inflating: flow_files_anon002_full/000550.flo
#   inflating: flow_files_anon002_full/000551.flo
#   inflating: flow_files_anon002_full/000552.flo
#   inflating: flow_files_anon002_full/000553.flo
#   inflating: flow_files_anon002_full/000554.flo
#   inflating: flow_files_anon002_full/000555.flo
#   inflating: flow_files_anon002_full/000556.flo
#   inflating: flow_files_anon002_full/000557.flo
#   inflating: flow_files_anon002_full/000558.flo
#   inflating: flow_files_anon002_full/000559.flo
#   inflating: flow_files_anon002_full/000560.flo
#   inflating: flow_files_anon002_full/000561.flo
#   inflating: flow_files_anon002_full/000562.flo
#   inflating: flow_files_anon002_full/000563.flo
#   inflating: flow_files_anon002_full/000564.flo
#   inflating: flow_files_anon002_full/000565.flo
#   inflating: flow_files_anon002_full/000566.flo
#   inflating: flow_files_anon002_full/000567.flo
#   inflating: flow_files_anon002_full/000568.flo
#   inflating: flow_files_anon002_full/000569.flo
#   inflating: flow_files_anon002_full/000570.flo
#   inflating: flow_files_anon002_full/000571.flo
#   inflating: flow_files_anon002_full/000572.flo
#   inflating: flow_files_anon002_full/000573.flo
#   inflating: flow_files_anon002_full/000574.flo
#   inflating: flow_files_anon002_full/000575.flo
#   inflating: flow_files_anon002_full/000576.flo
#   inflating: flow_files_anon002_full/000577.flo
#   inflating: flow_files_anon002_full/000578.flo
#   inflating: flow_files_anon002_full/000579.flo
#   inflating: flow_files_anon002_full/000580.flo
#   inflating: flow_files_anon002_full/000581.flo
#   inflating: flow_files_anon002_full/000582.flo
#   inflating: flow_files_anon002_full/000583.flo
#   inflating: flow_files_anon002_full/000584.flo
#   inflating: flow_files_anon002_full/000585.flo
#   inflating: flow_files_anon002_full/000586.flo
#   inflating: flow_files_anon002_full/000587.flo
#   inflating: flow_files_anon002_full/000588.flo
#   inflating: flow_files_anon002_full/000589.flo
#   inflating: flow_files_anon002_full/000590.flo
#   inflating: flow_files_anon002_full/000591.flo
#   inflating: flow_files_anon002_full/000592.flo
#   inflating: flow_files_anon002_full/000593.flo
#   inflating: flow_files_anon002_full/000594.flo
#   inflating: flow_files_anon002_full/000595.flo
#   inflating: flow_files_anon002_full/000596.flo
#   inflating: flow_files_anon002_full/000597.flo
#   inflating: flow_files_anon002_full/000598.flo
#   inflating: flow_files_anon002_full/000599.flo
#   inflating: flow_files_anon002_full/000600.flo
#   inflating: flow_files_anon002_full/000601.flo
#   inflating: flow_files_anon002_full/000602.flo
#   inflating: flow_files_anon002_full/000603.flo
#   inflating: flow_files_anon002_full/000604.flo
#   inflating: flow_files_anon002_full/000605.flo
#   inflating: flow_files_anon002_full/000606.flo
#   inflating: flow_files_anon002_full/000607.flo
#   inflating: flow_files_anon002_full/000608.flo
#   inflating: flow_files_anon002_full/000609.flo
#   inflating: flow_files_anon002_full/000610.flo
#   inflating: flow_files_anon002_full/000611.flo
#   inflating: flow_files_anon002_full/000612.flo
#   inflating: flow_files_anon002_full/000613.flo
#   inflating: flow_files_anon002_full/000614.flo
#   inflating: flow_files_anon002_full/000615.flo
#   inflating: flow_files_anon002_full/000616.flo
#   inflating: flow_files_anon002_full/000617.flo
#   inflating: flow_files_anon002_full/000618.flo
#   inflating: flow_files_anon002_full/000619.flo
#   inflating: flow_files_anon002_full/000620.flo
#   inflating: flow_files_anon002_full/000621.flo
#   inflating: flow_files_anon002_full/000622.flo
#   inflating: flow_files_anon002_full/000623.flo
#   inflating: flow_files_anon002_full/000624.flo
#   inflating: flow_files_anon002_full/000625.flo
#   inflating: flow_files_anon002_full/000626.flo
#   inflating: flow_files_anon002_full/000627.flo
#   inflating: flow_files_anon002_full/000628.flo
#   inflating: flow_files_anon002_full/000629.flo
#   inflating: flow_files_anon002_full/000630.flo
#   inflating: flow_files_anon002_full/000631.flo
#   inflating: flow_files_anon002_full/000632.flo
#   inflating: flow_files_anon002_full/000633.flo
#   inflating: flow_files_anon002_full/000634.flo
#   inflating: flow_files_anon002_full/000635.flo
#   inflating: flow_files_anon002_full/000636.flo
#   inflating: flow_files_anon002_full/000637.flo
#   inflating: flow_files_anon002_full/000638.flo
#   inflating: flow_files_anon002_full/000639.flo
#   inflating: flow_files_anon002_full/000640.flo
#   inflating: flow_files_anon002_full/000641.flo
#   inflating: flow_files_anon002_full/000642.flo
#   inflating: flow_files_anon002_full/000643.flo
#   inflating: flow_files_anon002_full/000644.flo
#   inflating: flow_files_anon002_full/000645.flo
#   inflating: flow_files_anon002_full/000646.flo
#   inflating: flow_files_anon002_full/000647.flo
#   inflating: flow_files_anon002_full/000648.flo
#   inflating: flow_files_anon002_full/000649.flo
#   inflating: flow_files_anon002_full/000650.flo
#   inflating: flow_files_anon002_full/000651.flo
#   inflating: flow_files_anon002_full/000652.flo
#   inflating: flow_files_anon002_full/000653.flo
#   inflating: flow_files_anon002_full/000654.flo
#   inflating: flow_files_anon002_full/000655.flo
#   inflating: flow_files_anon002_full/000656.flo
#   inflating: flow_files_anon002_full/000657.flo
#   inflating: flow_files_anon002_full/000658.flo
#   inflating: flow_files_anon002_full/000659.flo
#   inflating: flow_files_anon002_full/000660.flo
#   inflating: flow_files_anon002_full/000661.flo
#   inflating: flow_files_anon002_full/000662.flo
#   inflating: flow_files_anon002_full/000663.flo
#   inflating: flow_files_anon002_full/000664.flo
#   inflating: flow_files_anon002_full/000665.flo
#   inflating: flow_files_anon002_full/000666.flo
#   inflating: flow_files_anon002_full/000667.flo
#   inflating: flow_files_anon002_full/000668.flo
#   inflating: flow_files_anon002_full/000669.flo
#   inflating: flow_files_anon002_full/000670.flo
#   inflating: flow_files_anon002_full/000671.flo
#   inflating: flow_files_anon002_full/000672.flo
#   inflating: flow_files_anon002_full/000673.flo
#   inflating: flow_files_anon002_full/000674.flo
#   inflating: flow_files_anon002_full/000675.flo
#   inflating: flow_files_anon002_full/000676.flo
#   inflating: flow_files_anon002_full/000677.flo
#   inflating: flow_files_anon002_full/000678.flo
#   inflating: flow_files_anon002_full/000679.flo
#   inflating: flow_files_anon002_full/000680.flo
#   inflating: flow_files_anon002_full/000681.flo
#   inflating: flow_files_anon002_full/000682.flo
#   inflating: flow_files_anon002_full/000683.flo
#   inflating: flow_files_anon002_full/000684.flo
#   inflating: flow_files_anon002_full/000685.flo
#   inflating: flow_files_anon002_full/000686.flo
#   inflating: flow_files_anon002_full/000687.flo
#   inflating: flow_files_anon002_full/000688.flo
#   inflating: flow_files_anon002_full/000689.flo
#   inflating: flow_files_anon002_full/000690.flo
#   inflating: flow_files_anon002_full/000691.flo
#   inflating: flow_files_anon002_full/000692.flo
#   inflating: flow_files_anon002_full/000693.flo
#   inflating: flow_files_anon002_full/000694.flo
#   inflating: flow_files_anon002_full/000695.flo
#   inflating: flow_files_anon002_full/000696.flo
#   inflating: flow_files_anon002_full/000697.flo
#   inflating: flow_files_anon002_full/000698.flo
#   inflating: flow_files_anon002_full/000699.flo
#   inflating: flow_files_anon002_full/000700.flo
#   inflating: flow_files_anon002_full/000701.flo
#   inflating: flow_files_anon002_full/000702.flo
#   inflating: flow_files_anon002_full/000703.flo
#   inflating: flow_files_anon002_full/000704.flo
#   inflating: flow_files_anon002_full/000705.flo
#   inflating: flow_files_anon002_full/000706.flo
#   inflating: flow_files_anon002_full/000707.flo
#   inflating: flow_files_anon002_full/000708.flo
#   inflating: flow_files_anon002_full/000709.flo
#   inflating: flow_files_anon002_full/000710.flo
#   inflating: flow_files_anon002_full/000711.flo
#   inflating: flow_files_anon002_full/000712.flo
#   inflating: flow_files_anon002_full/000713.flo
#   inflating: flow_files_anon002_full/000714.flo
#   inflating: flow_files_anon002_full/000715.flo
#   inflating: flow_files_anon002_full/000716.flo
#   inflating: flow_files_anon002_full/000717.flo
#   inflating: flow_files_anon002_full/000718.flo
#   inflating: flow_files_anon002_full/000719.flo
#   inflating: flow_files_anon002_full/000720.flo
#   inflating: flow_files_anon002_full/000721.flo
#   inflating: flow_files_anon002_full/000722.flo
#   inflating: flow_files_anon002_full/000723.flo
#   inflating: flow_files_anon002_full/000724.flo
#   inflating: flow_files_anon002_full/000725.flo
#   inflating: flow_files_anon002_full/000726.flo
#   inflating: flow_files_anon002_full/000727.flo
#   inflating: flow_files_anon002_full/000728.flo
#   inflating: flow_files_anon002_full/000729.flo
#   inflating: flow_files_anon002_full/000730.flo
#   inflating: flow_files_anon002_full/000731.flo
#   inflating: flow_files_anon002_full/000732.flo
#   inflating: flow_files_anon002_full/000733.flo
#   inflating: flow_files_anon002_full/000734.flo
#   inflating: flow_files_anon002_full/000735.flo
#   inflating: flow_files_anon002_full/000736.flo
#   inflating: flow_files_anon002_full/000737.flo
#   inflating: flow_files_anon002_full/000738.flo
#   inflating: flow_files_anon002_full/000739.flo
#   inflating: flow_files_anon002_full/000740.flo
#   inflating: flow_files_anon002_full/000741.flo
#   inflating: flow_files_anon002_full/000742.flo
#   inflating: flow_files_anon002_full/000743.flo
#   inflating: flow_files_anon002_full/000744.flo
#   inflating: flow_files_anon002_full/000745.flo
#   inflating: flow_files_anon002_full/000746.flo
#   inflating: flow_files_anon002_full/000747.flo
#   inflating: flow_files_anon002_full/000748.flo
#   inflating: flow_files_anon002_full/000749.flo
#   inflating: flow_files_anon002_full/000750.flo
#   inflating: flow_files_anon002_full/000751.flo
#   inflating: flow_files_anon002_full/000752.flo
#   inflating: flow_files_anon002_full/000753.flo
#   inflating: flow_files_anon002_full/000754.flo
#   inflating: flow_files_anon002_full/000755.flo
#   inflating: flow_files_anon002_full/000756.flo
#   inflating: flow_files_anon002_full/000757.flo
#   inflating: flow_files_anon002_full/000758.flo
#   inflating: flow_files_anon002_full/000759.flo
#   inflating: flow_files_anon002_full/000760.flo
#   inflating: flow_files_anon002_full/000761.flo
#   inflating: flow_files_anon002_full/000762.flo
#   inflating: flow_files_anon002_full/000763.flo
#   inflating: flow_files_anon002_full/000764.flo
#   inflating: flow_files_anon002_full/000765.flo
#   inflating: flow_files_anon002_full/000766.flo
#   inflating: flow_files_anon002_full/000767.flo
#   inflating: flow_files_anon002_full/000768.flo
#   inflating: flow_files_anon002_full/000769.flo
#   inflating: flow_files_anon002_full/000770.flo
#   inflating: flow_files_anon002_full/000771.flo
#   inflating: flow_files_anon002_full/000772.flo
#   inflating: flow_files_anon002_full/000773.flo
#   inflating: flow_files_anon002_full/000774.flo
#   inflating: flow_files_anon002_full/000775.flo
#   inflating: flow_files_anon002_full/000776.flo
#   inflating: flow_files_anon002_full/000777.flo
#   inflating: flow_files_anon002_full/000778.flo
#   inflating: flow_files_anon002_full/000779.flo
#   inflating: flow_files_anon002_full/000780.flo
#   inflating: flow_files_anon002_full/000781.flo
#   inflating: flow_files_anon002_full/000782.flo
#   inflating: flow_files_anon002_full/000783.flo
#   inflating: flow_files_anon002_full/000784.flo
#   inflating: flow_files_anon002_full/000785.flo
#   inflating: flow_files_anon002_full/000786.flo
#   inflating: flow_files_anon002_full/000787.flo
#   inflating: flow_files_anon002_full/000788.flo
#   inflating: flow_files_anon002_full/000789.flo
#   inflating: flow_files_anon002_full/000790.flo
#   inflating: flow_files_anon002_full/000791.flo
#   inflating: flow_files_anon002_full/000792.flo
#   inflating: flow_files_anon002_full/000793.flo
#   inflating: flow_files_anon002_full/000794.flo
#   inflating: flow_files_anon002_full/000795.flo
#   inflating: flow_files_anon002_full/000796.flo
#   inflating: flow_files_anon002_full/000797.flo
#   inflating: flow_files_anon002_full/000798.flo
#   inflating: flow_files_anon002_full/000799.flo
#   inflating: flow_files_anon002_full/000800.flo
#   inflating: flow_files_anon002_full/000801.flo
#   inflating: flow_files_anon002_full/000802.flo
#   inflating: flow_files_anon002_full/000803.flo
#   inflating: flow_files_anon002_full/000804.flo
#   inflating: flow_files_anon002_full/000805.flo
#   inflating: flow_files_anon002_full/000806.flo
#   inflating: flow_files_anon002_full/000807.flo
#   inflating: flow_files_anon002_full/000808.flo
#   inflating: flow_files_anon002_full/000809.flo
#   inflating: flow_files_anon002_full/000810.flo
#   inflating: flow_files_anon002_full/000811.flo
#   inflating: flow_files_anon002_full/000812.flo
#   inflating: flow_files_anon002_full/000813.flo
#   inflating: flow_files_anon002_full/000814.flo
#   inflating: flow_files_anon002_full/000815.flo
#   inflating: flow_files_anon002_full/000816.flo
#   inflating: flow_files_anon002_full/000817.flo
#   inflating: flow_files_anon002_full/000818.flo
#   inflating: flow_files_anon002_full/000819.flo
#   inflating: flow_files_anon002_full/000820.flo
#   inflating: flow_files_anon002_full/000821.flo
#   inflating: flow_files_anon002_full/000822.flo
#   inflating: flow_files_anon002_full/000823.flo
#   inflating: flow_files_anon002_full/000824.flo
#   inflating: flow_files_anon002_full/000825.flo
#   inflating: flow_files_anon002_full/000826.flo
#   inflating: flow_files_anon002_full/000827.flo
#   inflating: flow_files_anon002_full/000828.flo
#   inflating: flow_files_anon002_full/000829.flo
#   inflating: flow_files_anon002_full/000830.flo
#   inflating: flow_files_anon002_full/000831.flo
#   inflating: flow_files_anon002_full/000832.flo
#   inflating: flow_files_anon002_full/000833.flo
#   inflating: flow_files_anon002_full/000834.flo
#   inflating: flow_files_anon002_full/000835.flo
#   inflating: flow_files_anon002_full/000836.flo
#   inflating: flow_files_anon002_full/000837.flo
#   inflating: flow_files_anon002_full/000838.flo
#   inflating: flow_files_anon002_full/000839.flo
#   inflating: flow_files_anon002_full/000840.flo
#   inflating: flow_files_anon002_full/000841.flo
#   inflating: flow_files_anon002_full/000842.flo
#   inflating: flow_files_anon002_full/000843.flo
#   inflating: flow_files_anon002_full/000844.flo
#   inflating: flow_files_anon002_full/000845.flo
#   inflating: flow_files_anon002_full/000846.flo
#   inflating: flow_files_anon002_full/000847.flo
#   inflating: flow_files_anon002_full/000848.flo
#   inflating: flow_files_anon002_full/000849.flo
#   inflating: flow_files_anon002_full/000850.flo
#   inflating: flow_files_anon002_full/000851.flo
#   inflating: flow_files_anon002_full/000852.flo
#   inflating: flow_files_anon002_full/000853.flo
#   inflating: flow_files_anon002_full/000854.flo
#   inflating: flow_files_anon002_full/000855.flo
#   inflating: flow_files_anon002_full/000856.flo
#   inflating: flow_files_anon002_full/000857.flo
#   inflating: flow_files_anon002_full/000858.flo
#   inflating: flow_files_anon002_full/000859.flo
#   inflating: flow_files_anon002_full/000860.flo
#   inflating: flow_files_anon002_full/000861.flo
#   inflating: flow_files_anon002_full/000862.flo
#   inflating: flow_files_anon002_full/000863.flo
#   inflating: flow_files_anon002_full/000864.flo
#   inflating: flow_files_anon002_full/000865.flo
#   inflating: flow_files_anon002_full/000866.flo
#   inflating: flow_files_anon002_full/000867.flo
#   inflating: flow_files_anon002_full/000868.flo
#   inflating: flow_files_anon002_full/000869.flo
#   inflating: flow_files_anon002_full/000870.flo
#   inflating: flow_files_anon002_full/000871.flo
#   inflating: flow_files_anon002_full/000872.flo
#   inflating: flow_files_anon002_full/000873.flo
#   inflating: flow_files_anon002_full/000874.flo
#   inflating: flow_files_anon002_full/000875.flo
#   inflating: flow_files_anon002_full/000876.flo
#   inflating: flow_files_anon002_full/000877.flo
#   inflating: flow_files_anon002_full/000878.flo
#   inflating: flow_files_anon002_full/000879.flo
#   inflating: flow_files_anon002_full/000880.flo
#   inflating: flow_files_anon002_full/000881.flo
#   inflating: flow_files_anon002_full/000882.flo
#   inflating: flow_files_anon002_full/000883.flo
#   inflating: flow_files_anon002_full/000884.flo
#   inflating: flow_files_anon002_full/000885.flo
#   inflating: flow_files_anon002_full/000886.flo
#   inflating: flow_files_anon002_full/000887.flo
#   inflating: flow_files_anon002_full/000888.flo
#   inflating: flow_files_anon002_full/000889.flo
#   inflating: flow_files_anon002_full/000890.flo
#   inflating: flow_files_anon002_full/000891.flo
#   inflating: flow_files_anon002_full/000892.flo
#   inflating: flow_files_anon002_full/000893.flo
#   inflating: flow_files_anon002_full/000894.flo
#   inflating: flow_files_anon002_full/000895.flo
#   inflating: flow_files_anon002_full/000896.flo
#   inflating: flow_files_anon002_full/000897.flo
#   inflating: flow_files_anon002_full/000898.flo
#   inflating: flow_files_anon002_full/000899.flo
#   inflating: flow_files_anon002_full/000900.flo
#   inflating: flow_files_anon002_full/000901.flo
#   inflating: flow_files_anon002_full/000902.flo
#   inflating: flow_files_anon002_full/000903.flo
#   inflating: flow_files_anon002_full/000904.flo
#   inflating: flow_files_anon002_full/000905.flo
#   inflating: flow_files_anon002_full/000906.flo
#   inflating: flow_files_anon002_full/000907.flo
#   inflating: flow_files_anon002_full/000908.flo
#   inflating: flow_files_anon002_full/000909.flo
#   inflating: flow_files_anon002_full/000910.flo
#   inflating: flow_files_anon002_full/000911.flo
#   inflating: flow_files_anon002_full/000912.flo
#   inflating: flow_files_anon002_full/000913.flo
#   inflating: flow_files_anon002_full/000914.flo
#   inflating: flow_files_anon002_full/000915.flo
#   inflating: flow_files_anon002_full/000916.flo
#   inflating: flow_files_anon002_full/000917.flo
#   inflating: flow_files_anon002_full/000918.flo
#   inflating: flow_files_anon002_full/000919.flo
#   inflating: flow_files_anon002_full/000920.flo
#   inflating: flow_files_anon002_full/000921.flo
#   inflating: flow_files_anon002_full/000922.flo
#   inflating: flow_files_anon002_full/000923.flo
#   inflating: flow_files_anon002_full/000924.flo
#   inflating: flow_files_anon002_full/000925.flo
#   inflating: flow_files_anon002_full/000926.flo
#   inflating: flow_files_anon002_full/000927.flo
#   inflating: flow_files_anon002_full/000928.flo
#   inflating: flow_files_anon002_full/000929.flo
#   inflating: flow_files_anon002_full/000930.flo
#   inflating: flow_files_anon002_full/000931.flo
#   inflating: flow_files_anon002_full/000932.flo
#   inflating: flow_files_anon002_full/000933.flo
#   inflating: flow_files_anon002_full/000934.flo
#   inflating: flow_files_anon002_full/000935.flo
#   inflating: flow_files_anon002_full/000936.flo
#   inflating: flow_files_anon002_full/000937.flo
#   inflating: flow_files_anon002_full/000938.flo
#   inflating: flow_files_anon002_full/000939.flo
#   inflating: flow_files_anon002_full/000940.flo
#   inflating: flow_files_anon002_full/000941.flo
#   inflating: flow_files_anon002_full/000942.flo
#   inflating: flow_files_anon002_full/000943.flo
#   inflating: flow_files_anon002_full/000944.flo
#   inflating: flow_files_anon002_full/000945.flo
#   inflating: flow_files_anon002_full/000946.flo
#   inflating: flow_files_anon002_full/000947.flo
#   inflating: flow_files_anon002_full/000948.flo
#   inflating: flow_files_anon002_full/000949.flo
#   inflating: flow_files_anon002_full/000950.flo
#   inflating: flow_files_anon002_full/000951.flo
#   inflating: flow_files_anon002_full/000952.flo
#   inflating: flow_files_anon002_full/000953.flo
#   inflating: flow_files_anon002_full/000954.flo
#   inflating: flow_files_anon002_full/000955.flo
#   inflating: flow_files_anon002_full/000956.flo
#   inflating: flow_files_anon002_full/000957.flo
# ...
#   inflating: anon002/anon002_02241.png
#   inflating: anon002/anon002_02242.png
#   inflating: anon002/anon002_02243.png
#   inflating: anon002/anon002_02244.png
#   inflating: anon002/anon002_02245.png
#   inflating: anon002/anon002_02246.png
#   inflating: anon002/anon002_02247.png
#   inflating: anon002/anon002_02248.png
#   inflating: anon002/anon002_02249.png
#   inflating: anon002/anon002_02250.png
#   inflating: anon002/anon002_02251.png
#   inflating: anon002/anon002_02252.png
#   inflating: anon002/anon002_02253.png
#   inflating: anon002/anon002_02254.png
#   inflating: anon002/anon002_02255.png
#   inflating: anon002/anon002_02256.png
#   inflating: anon002/anon002_02257.png
#   inflating: anon002/anon002_02258.png
#   inflating: anon002/anon002_02259.png
#   inflating: anon002/anon002_02260.png
#   inflating: anon002/anon002_02261.png
#   inflating: anon002/anon002_02262.png
#   inflating: anon002/anon002_02263.png
#   inflating: anon002/anon002_02264.png
#   inflating: anon002/anon002_02265.png
#   inflating: anon002/anon002_02266.png
#   inflating: anon002/anon002_02267.png
#   inflating: anon002/anon002_02268.png
#   inflating: anon002/anon002_02269.png
#   inflating: anon002/anon002_02270.png
#   inflating: anon002/anon002_02271.png
#   inflating: anon002/anon002_02272.png
#   inflating: anon002/anon002_02273.png
#   inflating: anon002/anon002_02274.png
#   inflating: anon002/anon002_02275.png
#   inflating: anon002/anon002_02276.png
#   inflating: anon002/anon002_02277.png
#   inflating: anon002/anon002_02278.png
#   inflating: anon002/anon002_02279.png
#   inflating: anon002/anon002_02280.png
#   inflating: anon002/anon002_02281.png
#   inflating: anon002/anon002_02282.png
#   inflating: anon002/anon002_02283.png
#   inflating: anon002/anon002_02284.png
#   inflating: anon002/anon002_02285.png
#   inflating: anon002/anon002_02286.png
#   inflating: anon002/anon002_02287.png
#   inflating: anon002/anon002_02288.png
#   inflating: anon002/anon002_02289.png
#   inflating: anon002/anon002_02290.png
#   inflating: anon002/anon002_02291.png
#   inflating: anon002/anon002_02292.png
#   inflating: anon002/anon002_02293.png
#   inflating: anon002/anon002_02294.png
#   inflating: anon002/anon002_02295.png
#   inflating: anon002/anon002_02296.png
#   inflating: anon002/anon002_02297.png
#   inflating: anon002/anon002_02298.png
#   inflating: anon002/anon002_02299.png
#   inflating: anon002/anon002_02300.png
#   inflating: anon002/anon002_02301.png
#   inflating: anon002/anon002_02302.png
#   inflating: anon002/anon002_02303.png
#   inflating: anon002/anon002_02304.png
#   inflating: anon002/anon002_02305.png
#   inflating: anon002/anon002_02306.png
#   inflating: anon002/anon002_02307.png
#   inflating: anon002/anon002_02308.png
#   inflating: anon002/anon002_02309.png
#   inflating: anon002/anon002_02310.png
#   inflating: anon002/anon002_02311.png
#   inflating: anon002/anon002_02312.png
#   inflating: anon002/anon002_02313.png
#   inflating: anon002/anon002_02314.png
#   inflating: anon002/anon002_02315.png
#   inflating: anon002/anon002_02316.png
#   inflating: anon002/anon002_02317.png
#   inflating: anon002/anon002_02318.png
#   inflating: anon002/anon002_02319.png
#   inflating: anon002/anon002_02320.png
#   inflating: anon002/anon002_02321.png
#   inflating: anon002/anon002_02322.png
#   inflating: anon002/anon002_02323.png
#   inflating: anon002/anon002_02324.png
#   inflating: anon002/anon002_02325.png
#   inflating: anon002/anon002_02326.png
#   inflating: anon002/anon002_02327.png
#   inflating: anon002/anon002_02328.png
#   inflating: anon002/anon002_02329.png
#   inflating: anon002/anon002_02330.png
#   inflating: anon002/anon002_02331.png
#   inflating: anon002/anon002_02332.png
#   inflating: anon002/anon002_02333.png
#   inflating: anon002/anon002_02334.png
#   inflating: anon002/anon002_02335.png
#   inflating: anon002/anon002_02336.png
#   inflating: anon002/anon002_02337.png
#   inflating: anon002/anon002_02338.png
#   inflating: anon002/anon002_02339.png
#   inflating: anon002/anon002_02340.png
#   inflating: anon002/anon002_02341.png
#   inflating: anon002/anon002_02342.png
#   inflating: anon002/anon002_02343.png
#   inflating: anon002/anon002_02344.png
#   inflating: anon002/anon002_02345.png
#   inflating: anon002/anon002_02346.png
#   inflating: anon002/anon002_02347.png
#   inflating: anon002/anon002_02348.png
#   inflating: anon002/anon002_02349.png
#   inflating: anon002/anon002_02350.png
#   inflating: anon002/anon002_02351.png
#   inflating: anon002/anon002_02352.png
#   inflating: anon002/anon002_02353.png
#   inflating: anon002/anon002_02354.png
#   inflating: anon002/anon002_02355.png
#   inflating: anon002/anon002_02356.png
#   inflating: anon002/anon002_02357.png
#   inflating: anon002/anon002_02358.png
#   inflating: anon002/anon002_02359.png
#   inflating: anon002/anon002_02360.png
#   inflating: anon002/anon002_02361.png
#   inflating: anon002/anon002_02362.png
#   inflating: anon002/anon002_02363.png
#   inflating: anon002/anon002_02364.png
#   inflating: anon002/anon002_02365.png
#   inflating: anon002/anon002_02366.png
#   inflating: anon002/anon002_02367.png
#   inflating: anon002/anon002_02368.png
#   inflating: anon002/anon002_02369.png
#   inflating: anon002/anon002_02370.png
#   inflating: anon002/anon002_02371.png
#   inflating: anon002/anon002_02372.png
#   inflating: anon002/anon002_02373.png
#   inflating: anon002/anon002_02374.png
#   inflating: anon002/anon002_02375.png
#   inflating: anon002/anon002_02376.png
#   inflating: anon002/anon002_02377.png
#   inflating: anon002/anon002_02378.png
#   inflating: anon002/anon002_02379.png
#   inflating: anon002/anon002_02380.png
#   inflating: anon002/anon002_02381.png
#   inflating: anon002/anon002_02382.png
#   inflating: anon002/anon002_02383.png
#   inflating: anon002/anon002_02384.png
#   inflating: anon002/anon002_02385.png
#   inflating: anon002/anon002_02386.png
#   inflating: anon002/anon002_02387.png
#   inflating: anon002/anon002_02388.png
#   inflating: anon002/anon002_02389.png
#   inflating: anon002/anon002_02390.png
#   inflating: anon002/anon002_02391.png
#   inflating: anon002/anon002_02392.png
#   inflating: anon002/anon002_02393.png
#   inflating: anon002/anon002_02394.png
#   inflating: anon002/anon002_02395.png
#   inflating: anon002/anon002_02396.png
#   inflating: anon002/anon002_02397.png
#   inflating: anon002/anon002_02398.png
#   inflating: anon002/anon002_02399.png
#   inflating: anon002/anon002_02400.png
#   inflating: anon002/anon002_02401.png
#   inflating: anon002/anon002_02402.png
#   inflating: anon002/anon002_02403.png
#   inflating: anon002/anon002_02404.png
#   inflating: anon002/anon002_02405.png
#   inflating: anon002/anon002_02406.png
#   inflating: anon002/anon002_02407.png
#   inflating: anon002/anon002_02408.png
#   inflating: anon002/anon002_02409.png
#   inflating: anon002/anon002_02410.png
#   inflating: anon002/anon002_02411.png
#   inflating: anon002/anon002_02412.png
#   inflating: anon002/anon002_02413.png
#   inflating: anon002/anon002_02414.png
#   inflating: anon002/anon002_02415.png
#   inflating: anon002/anon002_02416.png
#   inflating: anon002/anon002_02417.png
#   inflating: anon002/anon002_02418.png
#   inflating: anon002/anon002_02419.png
#   inflating: anon002/anon002_02420.png
#   inflating: anon002/anon002_02421.png
#   inflating: anon002/anon002_02422.png
#   inflating: anon002/anon002_02423.png
#   inflating: anon002/anon002_02424.png
#   inflating: anon002/anon002_02425.png
#   inflating: anon002/anon002_02426.png
#   inflating: anon002/anon002_02427.png
#   inflating: anon002/anon002_02428.png
#   inflating: anon002/anon002_02429.png
#   inflating: anon002/anon002_02430.png
#   inflating: anon002/anon002_02431.png
#   inflating: anon002/anon002_02432.png
#   inflating: anon002/anon002_02433.png
#   inflating: anon002/anon002_02434.png
#   inflating: anon002/anon002_02435.png
#   inflating: anon002/anon002_02436.png
#   inflating: anon002/anon002_02437.png
#   inflating: anon002/anon002_02438.png
#   inflating: anon002/anon002_02439.png
#   inflating: anon002/anon002_02440.png
#   inflating: anon002/anon002_02441.png
#   inflating: anon002/anon002_02442.png
#   inflating: anon002/anon002_02443.png
#   inflating: anon002/anon002_02444.png
#   inflating: anon002/anon002_02445.png
#   inflating: anon002/anon002_02446.png
#   inflating: anon002/anon002_02447.png
#   inflating: anon002/anon002_02448.png
#   inflating: anon002/anon002_02449.png
#   inflating: anon002/anon002_02450.png
#   inflating: anon002/anon002_02451.png
#   inflating: anon002/anon002_02452.png
#   inflating: anon002/anon002_02453.png
#   inflating: anon002/anon002_02454.png
#   inflating: anon002/anon002_02455.png
#   inflating: anon002/anon002_02456.png
#   inflating: anon002/anon002_02457.png
#   inflating: anon002/anon002_02458.png
#   inflating: anon002/anon002_02459.png
#   inflating: anon002/anon002_02460.png
#   inflating: anon002/anon002_02461.png
#   inflating: anon002/anon002_02462.png
#   inflating: anon002/anon002_02463.png
#   inflating: anon002/anon002_02464.png
#   inflating: anon002/anon002_02465.png
#   inflating: anon002/anon002_02466.png
#   inflating: anon002/anon002_02467.png
#   inflating: anon002/anon002_02468.png
#   inflating: anon002/anon002_02469.png
#   inflating: anon002/anon002_02470.png
#   inflating: anon002/anon002_02471.png
#   inflating: anon002/anon002_02472.png
#   inflating: anon002/anon002_02473.png
#   inflating: anon002/anon002_02474.png
#   inflating: anon002/anon002_02475.png
#   inflating: anon002/anon002_02476.png
#   inflating: anon002/anon002_02477.png
#   inflating: anon002/anon002_02478.png
#   inflating: anon002/anon002_02479.png
#   inflating: anon002/anon002_02480.png
#   inflating: anon002/anon002_02481.png
#   inflating: anon002/anon002_02482.png
#   inflating: anon002/anon002_02483.png
#   inflating: anon002/anon002_02484.png
#   inflating: anon002/anon002_02485.png
#   inflating: anon002/anon002_02486.png
#   inflating: anon002/anon002_02487.png
#   inflating: anon002/anon002_02488.png
#   inflating: anon002/anon002_02489.png
#   inflating: anon002/anon002_02490.png
#   inflating: anon002/anon002_02491.png
#   inflating: anon002/anon002_02492.png
#   inflating: anon002/anon002_02493.png
#   inflating: anon002/anon002_02494.png
#   inflating: anon002/anon002_02495.png
#   inflating: anon002/anon002_02496.png
#   inflating: anon002/anon002_02497.png
#   inflating: anon002/anon002_02498.png
#   inflating: anon002/anon002_02499.png
#   inflating: anon002/anon002_02500.png
#   inflating: anon002/anon002_02501.png
#   inflating: anon002/anon002_02502.png
#   inflating: anon002/anon002_02503.png
#   inflating: anon002/anon002_02504.png
#   inflating: anon002/anon002_02505.png
#   inflating: anon002/anon002_02506.png
#   inflating: anon002/anon002_02507.png
#   inflating: anon002/anon002_02508.png
#   inflating: anon002/anon002_02509.png
#   inflating: anon002/anon002_02510.png
#   inflating: anon002/anon002_02511.png
#   inflating: anon002/anon002_02512.png
#   inflating: anon002/anon002_02513.png
#   inflating: anon002/anon002_02514.png
#   inflating: anon002/anon002_02515.png
#   inflating: anon002/anon002_02516.png
#   inflating: anon002/anon002_02517.png
#   inflating: anon002/anon002_02518.png
#   inflating: anon002/anon002_02519.png
#   inflating: anon002/anon002_02520.png
#   inflating: anon002/anon002_02521.png
#   inflating: anon002/anon002_02522.png
#   inflating: anon002/anon002_02523.png
#   inflating: anon002/anon002_02524.png
#   inflating: anon002/anon002_02525.png
#   inflating: anon002/anon002_02526.png
#   inflating: anon002/anon002_02527.png
#   inflating: anon002/anon002_02528.png
#   inflating: anon002/anon002_02529.png
#   inflating: anon002/anon002_02530.png
#   inflating: anon002/anon002_02531.png
#   inflating: anon002/anon002_02532.png
#   inflating: anon002/anon002_02533.png
#   inflating: anon002/anon002_02534.png
#   inflating: anon002/anon002_02535.png
#   inflating: anon002/anon002_02536.png
#   inflating: anon002/anon002_02537.png
#   inflating: anon002/anon002_02538.png
#   inflating: anon002/anon002_02539.png
#   inflating: anon002/anon002_02540.png
#   inflating: anon002/anon002_02541.png
#   inflating: anon002/anon002_02542.png
#   inflating: anon002/anon002_02543.png
#   inflating: anon002/anon002_02544.png
#   inflating: anon002/anon002_02545.png
#   inflating: anon002/anon002_02546.png
#   inflating: anon002/anon002_02547.png
#   inflating: anon002/anon002_02548.png
#   inflating: anon002/anon002_02549.png
#   inflating: anon002/anon002_02550.png
#   inflating: anon002/anon002_02551.png
#   inflating: anon002/anon002_02552.png
#   inflating: anon002/anon002_02553.png
#   inflating: anon002/anon002_02554.png
#   inflating: anon002/anon002_02555.png
#   inflating: anon002/anon002_02556.png
#   inflating: anon002/anon002_02557.png
#   inflating: anon002/anon002_02558.png
#   inflating: anon002/anon002_02559.png
#   inflating: anon002/anon002_02560.png
#   inflating: anon002/anon002_02561.png
#   inflating: anon002/anon002_02562.png
#   inflating: anon002/anon002_02563.png
#   inflating: anon002/anon002_02564.png
#   inflating: anon002/anon002_02565.png
#   inflating: anon002/anon002_02566.png
#   inflating: anon002/anon002_02567.png
#   inflating: anon002/anon002_02568.png
#   inflating: anon002/anon002_02569.png
#   inflating: anon002/anon002_02570.png
#   inflating: anon002/anon002_02571.png
#   inflating: anon002/anon002_02572.png
#   inflating: anon002/anon002_02573.png
#   inflating: anon002/anon002_02574.png
#   inflating: anon002/anon002_02575.png
#   inflating: anon002/anon002_02576.png
#   inflating: anon002/anon002_02577.png
#   inflating: anon002/anon002_02578.png
#   inflating: anon002/anon002_02579.png
#   inflating: anon002/anon002_02580.png
#   inflating: anon002/anon002_02581.png
#   inflating: anon002/anon002_02582.png
#   inflating: anon002/anon002_02583.png
#   inflating: anon002/anon002_02584.png
#   inflating: anon002/anon002_02585.png
#   inflating: anon002/anon002_02586.png
#   inflating: anon002/anon002_02587.png
#   inflating: anon002/anon002_02588.png
#   inflating: anon002/anon002_02589.png
#   inflating: anon002/anon002_02590.png
#   inflating: anon002/anon002_02591.png
#   inflating: anon002/anon002_02592.png
#   inflating: anon002/anon002_02593.png
#   inflating: anon002/anon002_02594.png
#   inflating: anon002/anon002_02595.png
#   inflating: anon002/anon002_02596.png
#   inflating: anon002/anon002_02597.png
#   inflating: anon002/anon002_02598.png
#   inflating: anon002/anon002_02599.png
#   inflating: anon002/anon002_02600.png
#   inflating: anon002/anon002_02601.png
#   inflating: anon002/anon002_02602.png
#   inflating: anon002/anon002_02603.png
#   inflating: anon002/anon002_02604.png
#   inflating: anon002/anon002_02605.png
#   inflating: anon002/anon002_02606.png
#   inflating: anon002/anon002_02607.png
#   inflating: anon002/anon002_02608.png
#   inflating: anon002/anon002_02609.png
#   inflating: anon002/anon002_02610.png
#   inflating: anon002/anon002_02611.png
#   inflating: anon002/anon002_02612.png
#   inflating: anon002/anon002_02613.png
#   inflating: anon002/anon002_02614.png
#   inflating: anon002/anon002_02615.png
#   inflating: anon002/anon002_02616.png
#   inflating: anon002/anon002_02617.png
#   inflating: anon002/anon002_02618.png
#   inflating: anon002/anon002_02619.png
#   inflating: anon002/anon002_02620.png
#   inflating: anon002/anon002_02621.png
#   inflating: anon002/anon002_02622.png
#   inflating: anon002/anon002_02623.png
#   inflating: anon002/anon002_02624.png
#   inflating: anon002/anon002_02625.png
#   inflating: anon002/anon002_02626.png
#   inflating: anon002/anon002_02627.png
#   inflating: anon002/anon002_02628.png
#   inflating: anon002/anon002_02629.png
#   inflating: anon002/anon002_02630.png

# %%
# !pip uninstall opencv-python -y
# downgrade OpenCV a bit since some none-free features are not avilable
# !pip install opencv-contrib-python==3.4.2.17 --force-reinstall
# Out:
# Uninstalling opencv-python-4.1.2.30:
#   Successfully uninstalled opencv-python-4.1.2.30
# Collecting opencv-contrib-python==3.4.2.17
#   Downloading https://files.pythonhosted.org/packages/61/29/fc60b2de1713aa92946992544329f20ccb5e4ba26290f403e04b7da44105/opencv_contrib_python-3.4.2.17-cp36-cp36m-manylinux1_x86_64.whl (30.6MB)
#      |████████████████████████████████| 30.6MB 139kB/s
# Collecting numpy>=1.11.3
#   Downloading https://files.pythonhosted.org/packages/14/32/d3fa649ad7ec0b82737b92fefd3c4dd376b0bb23730715124569f38f3a08/numpy-1.19.5-cp36-cp36m-manylinux2010_x86_64.whl (14.8MB)
#      |████████████████████████████████| 14.8MB 42.7MB/s
# ERROR: imgaug 0.2.9 requires opencv-python, which is not installed.
# ERROR: dopamine-rl 1.0.5 requires opencv-python>=3.4.1.15, which is not installed.
# ERROR: albumentations 0.1.12 requires opencv-python, which is not installed.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: numpy, opencv-contrib-python
#   Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Found existing installation: opencv-contrib-python 4.1.2.30
#     Uninstalling opencv-contrib-python-4.1.2.30:
#       Successfully uninstalled opencv-contrib-python-4.1.2.30
# Successfully installed numpy-1.19.5 opencv-contrib-python-3.4.2.17

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import imageio
cv2.ocl.setUseOpenCL(False)
import sys
from PIL import Image
from pathlib import Path
from os import listdir

# %%
flowFileDirPath = '/content/flow_files_anon002_full'
fullImgDirPath = '/content/anon002'
transformation = "Affine"
mask_path = '/content/masks/anon002_mask.png'
padding_size = 1000

# %%
flowPaths =  [ flowFileDirPath + '/' + f  for f  in sorted(listdir(flowFileDirPath))]
fullImgPaths =  [ fullImgDirPath + '/' + f  for f  in sorted(listdir(fullImgDirPath))]

# %%
img_1 = cv2.imread(fullImgPaths[0])
img_1 = cv2.cvtColor(img_1,cv2.COLOR_BGR2RGB)

mask_im = Image.open(mask_path)
mask_im = mask_im.resize((img_1.shape[0], img_1.shape[1]), Image.ANTIALIAS)
mask_im = np.array(mask_im) * np.uint8(255)
mask_im = cv2.resize(mask_im, img_1.shape[1::-1])

# %%
def inputAndVisualizeStitchPair(srcImgPath, destImgPath, showImages=True): 
  '''
    Inputs: srcImgPath, destImgPath 
    srcImgPath : path to the image been transformed, usually the new frame seen ->str
    destImgPath : path to the image that acts as destination(src image is trasformed to it), usually the old frame->str
    Output: [srcImg, destImg] -> list
    srcImg: 256x256 representation of srcImage ->ndarray
    destImg: 256x256 representation of destImage ->ndarray
  '''
  srcImg = cv2.imread(srcImgPath)
  srcImg = cv2.cvtColor(srcImg,cv2.COLOR_BGR2RGB)
  srcImg_gray = cv2.cvtColor(srcImg, cv2.COLOR_RGB2GRAY)

  destImg = cv2.imread(destImgPath)
  destImg = cv2.cvtColor(destImg,cv2.COLOR_BGR2RGB)
  destImg_gray = cv2.cvtColor(destImg, cv2.COLOR_RGB2GRAY)

  if showImages:
    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, constrained_layout=False, figsize=(10,4))
    ax1.imshow(destImg, cmap="gray")
    ax1.set_xlabel("dest image", fontsize=14)

    ax2.imshow(srcImg, cmap="gray")
    ax2.set_xlabel("Src image (Image to be transformed)", fontsize=14)
    
    plt.show()

  return [srcImg, destImg]

# %%
def inputAndFormatFlowfile(flowPath):
  '''
  Input: flowPath
  flowpath: path to the .flo file between two images ->str
  Output: flow
  flow: the formated optical_flow -> ndArray of heightxbreathx2 of the image sizes 
  '''
  path = Path(flowPath) 
  with path.open(mode='r') as flo:
      np_flow = np.fromfile(flo, np.float32)
      # print(np_flow.shape)

  with path.open(mode='r') as flo:
    tag = np.fromfile(flo, np.float32, count=1)[0]
    width = np.fromfile(flo, np.int32, count=1)[0]
    height = np.fromfile(flo, np.int32, count=1)[0]

    print('tag', tag, 'width', width, 'height', height)

    nbands = 2
    tmp = np.fromfile(flo, np.float32, count= nbands * width * height)
    flow = np.resize(tmp, (int(height), int(width), int(nbands)))
    return flow

# %%
def getCameraPixels(img):

  img = cv2.bitwise_and(img, img, mask=mask_im)
  # _,  imgMask = cv2.threshold(img,5,255,cv2.THRESH_BINARY)

  imgMaskGray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)


  nonZero = cv2.findNonZero(imgMaskGray)
  I,J = np.transpose(nonZero).squeeze()

  return [I, J]

# %%
def pointCorrespondenceFromOpticalFlow(flow, padding, nonZeroI, nonZeroJ):
  '''
  Input: flow
  flow: the formatted optical flow file -> ndarray length,breadth,2
  padding: padding to add to destImg
  OutPut: [ptsA and ptsB] -> list
  ptsA: point correspondences in the destImg (original) -> ndarray length*breadth,2
  ptsB: point correspondences in the srcImg(new, been transformed) -> ndarray length*breadth,2
  '''
  ptsA = np.zeros(flow.shape)
  ptsB = np.zeros(flow.shape)


  for i in range(ptsA.shape[0]):
    for j in range(ptsA.shape[1]):
      ptsA[i,j] = np.array([i,j], dtype=np.float)
      ptsB[i,j] = np.array([i,j])  +  (np.array(flow[j, i]))

  # print("before ptsA", ptsA.shape)
  # print("check ptsA", ptsA[217, 8] )
  # print("check ptsB", ptsB[217, 8] )
  
  ptsA = ptsA[nonZeroI,nonZeroJ]
  ptsB = ptsB[nonZeroI,nonZeroJ]

  # print("after ptsA", ptsA.shape)
  # print("after check ptsA", ptsA[0] )

  return [ptsA, ptsB]

# %%
def findTransformation(ptsA, ptsB, threshold=1):
  '''
    ptsA: point correspondences in the destImg (original) -> ndarray length*breadth,2
    ptsB: point correspondences in the srcImg(new, been transformed) -> ndarray length*breadth,2
    threshold: ransac threshold. 
    Output:
    H - homography
    status - mask of ransac accepted or rejected
  '''
  if transformation == "Homography":
    (H, status) = cv2.findHomography(ptsB, ptsA, cv2.RANSAC, threshold)
  elif transformation == "Affine":
    (H, status) = cv2.estimateAffine2D(ptsB, ptsA, method = cv2.RANSAC, ransacReprojThreshold = threshold)
  return [H, status]

# %%
def visualizeStitch(srcImg, destImg, H, padding, showImages=True):
  '''
  srcImg: 256x256 representation of srcImage ->ndarray
  destImg: 256x256 representation of destImage ->ndarray
  H - homography
  '''
  ht, wd, cc= destImg.shape

  ww = wd + (2*padding)
  hh = ht + (2*padding)

  xx = (ww - wd) // 2
  yy = (hh - ht) // 2

  if transformation == "Homography":
    result = cv2.warpPerspective(srcImg, H, (ww, hh))
  elif transformation == "Affine":
    result = cv2.warpAffine(srcImg, H, (ww, hh))

  alpha_s = mask_im/ 255.0
  alpha_l = 1.0 - alpha_s

  for c in range(0, 3):
      result[yy:yy+ht, xx:xx+wd, c] = (alpha_s * destImg[:, :, c] +
                                alpha_l * result[yy:yy+ht, xx:xx+wd, c])
  
  print("Visualize stitch")
  if showImages:
    plt.figure(figsize=(10,4))
    plt.imshow(result)

    plt.show()

# %%
# b = np.arange(16).reshape((4,4))
# b_3d = b[:, :, None] * np.ones(3, dtype=int)[None, None, :]
# print(b)
# print(1-b_3d[:,:,2])

# %%
image_width = 256
def VisualizeOutliers(destImgPath, status, showImages):
  if showImages:
    ransac_fail = np.where(np.any(status==0, axis=1))[0]
    convert_to_pixel = lambda t: [t//image_width, t%image_width]
    outlier_pixels = np.array([convert_to_pixel(p) for p in ransac_fail])
    # print(outlier_pixels)
    destImg = Image.open(destImgPath)
    fig = plt.figure(figsize=(10,4))
    plt.xlabel("outliers",fontsize=14)
    if (outlier_pixels.size):
      plt.plot(outlier_pixels[:, 1],outlier_pixels[:, 0],'r.')
    plt.imshow(destImg)

# %%
def plotPixels(img, I, J):
  fig = plt.figure(figsize=(10,4))
  plt.plot(I,J,'r.')
  plt.imshow(img)
  plt.show()

# %% [markdown]
# #### Use functions to perform first stitch.

# %%
# srcImgPath = '/content/video01/anon001_00852.png'
# destImgPath = '/content/video01/anon001_00851.png'
# flowPath = '/content/flow_files_video01_full/000000.flo'
# padding = 0
# threshold = 7
# showImages = True

# srcImg, destImg = inputAndVisualizeStitchPair(srcImgPath, destImgPath, showImages)
# flow = inputAndFormatFlowfile(flowPath)

# I, J = getCameraPixels(destImg)
# # plotPixels(destImg, I, J)

# ptsA, ptsB =  pointCorrespondenceFromOpticalFlow(flow, padding, I , J)
# H, status = findTransformation(ptsA, ptsB, threshold)

# print(H)

# visualizeStitch(srcImg, destImg, H, padding, showImages)

# %% [markdown]
# ### mosaic registration

# %% [markdown]
# I used a crude way to make the mosaic here. I placed the first image into a very big blank canvas, then warped all the consecutive images towards it.
#
# There is a better method where you can choose whichever image you want as reference frame (such as the center image). This is shown in the get_lucas_kanade_mosaic.ipynb file and the global_registration_ongoing.ipynb file

# %%
def pointCorrespondenceWithoutPadding(flow, nonZeroI, nonZeroJ):
  '''
  Input: flow
  flow: the formatted optical flow file -> ndarray length,breadth,2
  padding: padding to add to destImg
  OutPut: [ptsA and ptsB] -> list
  ptsA: point correspondences in the destImg (original) -> ndarray length*breadth,2
  ptsB: point correspondences in the srcImg(new, been transformed) -> ndarray length*breadth,2
  '''
  ptsA = np.zeros(flow.shape)
  ptsB = np.zeros(flow.shape)

  for i in range(ptsA.shape[0]):
    for j in range(ptsA.shape[1]):
      ptsA[i,j] = np.array([i,j], dtype=np.float)
      ptsB[i,j] = np.array([i,j])  +  (np.array(flow[j,i]))

  ptsA = ptsA[nonZeroI,nonZeroJ]
  ptsB = ptsB[nonZeroI,nonZeroJ]

  ptsA = np.reshape(ptsA, (-1, 2))
  ptsB = np.reshape(ptsB, (-1, 2))
  return [ptsA, ptsB]

# %%
def pointCorrespondenceWithPaddingForFirst(flow, nonZeroI, nonZeroJ, padding= padding_size):
  '''
  Input: flow
  flow: the formatted optical flow file -> ndarray length,breadth,2
  padding: padding to add to destImg
  OutPut: [ptsA and ptsB] -> list
  ptsA: point correspondences in the destImg (original) -> ndarray length*breadth,2
  ptsB: point correspondences in the srcImg(new, been transformed) -> ndarray length*breadth,2
  '''
  ptsA = np.zeros(flow.shape)
  ptsB = np.zeros(flow.shape)

  for i in range(ptsA.shape[0]):
    for j in range(ptsA.shape[1]):
      ptsA[i,j] = np.array([i,j], dtype=np.float) + np.array([padding,padding])
      ptsB[i,j] = np.array([i,j])  +  (np.array(flow[j,i]))


  ptsA = ptsA[nonZeroI,nonZeroJ]
  ptsB = ptsB[nonZeroI,nonZeroJ]

  ptsA = np.reshape(ptsA, (-1, 2))
  ptsB = np.reshape(ptsB, (-1, 2))
  return [ptsA, ptsB]

# %%
padding = padding_size
threshold = 7
if transformation == "Homography":
  H_array = np.zeros((len(fullImgPaths)-1, 3,3 ))
elif transformation == "Affine":    
  H_array = np.zeros((len(fullImgPaths)-1, 2,3 ))
showImages = False

# %%
for i in range(len(fullImgPaths) - 1): #
  destImgPath = fullImgPaths[i] #the previous image
  srcImgPath =  fullImgPaths[i + 1];
  flowPath = flowPaths[i]

  srcImg, destImg = inputAndVisualizeStitchPair(srcImgPath, destImgPath, showImages)
  flow = inputAndFormatFlowfile(flowPath)
  I, J = getCameraPixels(destImg)

  if i==0:
    ptsA, ptsB = pointCorrespondenceWithPaddingForFirst(flow, I, J, padding)
  else:
    ptsA, ptsB = pointCorrespondenceWithoutPadding(flow, I, J)
  H, status = findTransformation(ptsA, ptsB, threshold)
  if i==0:
    visualizeStitch(srcImg, destImg, H, padding, showImages)
  else:
    visualizeStitch(srcImg, destImg, H, 0, showImages)

  H_array[i] = H
# Out:
# tag 202021.25 width 512 height 512
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-d2bc86e99e32> in <module>()
#       9
#      10   if i==0:
# ---> 11     ptsA, ptsB = pointCorrespondenceWithPaddingForFirst(flow, I, J, padding)
#      12   else:
#      13     ptsA, ptsB = pointCorrespondenceWithoutPadding(flow, I, J)
#
# <ipython-input-17-91a655ce463f> in pointCorrespondenceWithPaddingForFirst(flow, nonZeroI, nonZeroJ, padding)
#      17
#      18
# ---> 19   ptsA = ptsA[nonZeroI,nonZeroJ]
#      20   ptsB = ptsB[nonZeroI,nonZeroJ]
#      21
#
# IndexError: index 512 is out of bounds for axis 0 with size 512

# %%
H_array
# Out:
# array([[[ 9.98984573e-01,  1.75080357e-02,  9.93936478e+02],
#         [-1.17374084e-02,  9.97045965e-01,  1.00138521e+03]],
#
#        [[ 1.00349058e+00,  1.69731943e-02, -7.79437433e+00],
#         [-3.21567142e-03,  1.00755193e+00, -2.57728448e+00]],
#
#        [[ 1.00040670e+00,  2.41963286e-02, -1.29477290e+01],
#         [-1.23762075e-02,  1.01161244e+00, -7.13711270e+00]],
#
#        [[ 1.00850485e+00,  4.71653904e-04, -9.55962143e+00],
#         [-2.61926231e-04,  1.00390680e+00, -1.27676030e+01]],
#
#        [[ 1.00248666e+00,  7.79684871e-03, -7.62591505e+00],
#         [ 1.25624238e-03,  1.00474119e+00, -1.35965299e+01]],
#
#        [[ 1.01371220e+00,  4.06457071e-02, -1.97782651e+01],
#         [-9.31065418e-04,  1.02186224e+00, -1.45509891e+01]],
#
#        [[ 1.01314253e+00,  3.57943286e-02, -2.75666603e+01],
#         [-7.61742330e-03,  1.01583733e+00, -7.05882107e+00]],
#
#        [[ 9.98631357e-01,  9.59689202e-02, -3.67038088e+01],
#         [-2.05501217e-02,  1.01923775e+00, -1.93083857e+00]],
#
#        [[ 9.98375802e-01,  3.71124751e-02, -3.10384656e+01],
#         [-1.54525147e-02,  9.98734095e-01,  2.34531716e+00]],
#
#        [[ 9.97813814e-01,  5.48388978e-02, -3.14396886e+01],
#         [-1.26470215e-02,  9.86902016e-01,  8.00792484e+00]],
#
#        [[ 1.00107543e+00,  3.28137705e-02, -2.08148801e+01],
#         [-1.37932415e-02,  1.00419890e+00, -3.99885470e+00]],
#
#        [[ 1.00536373e+00,  1.66369878e-02, -1.10448534e+01],
#         [-2.70773995e-03,  1.00662959e+00, -5.43753684e+00]],
#
#        [[ 1.00259199e+00,  3.48731331e-02, -1.57207832e+01],
#         [-8.45893398e-03,  1.00870058e+00, -5.06033981e+00]],
#
#        [[ 1.00319406e+00,  1.42177716e-02, -1.08607922e+01],
#         [-1.00088662e-02,  1.00973143e+00, -6.71463492e+00]],
#
#        [[ 9.94105278e-01,  4.87360140e-03, -4.07839070e+00],
#         [-1.14458243e-02,  9.96134629e-01,  1.04726895e+00]],
#
#        [[ 9.96570527e-01,  1.55052171e-02, -1.03212047e+01],
#         [-9.94373308e-03,  9.98292231e-01, -5.78590629e+00]],
#
#        [[ 9.90175037e-01,  1.16970278e-02, -5.95343725e+00],
#         [-9.01600558e-03,  1.00477996e+00, -8.36582204e+00]],
#
#        [[ 1.00104893e+00, -5.87195189e-03, -2.76573363e+00],
#         [-1.22074395e-03,  1.00582970e+00, -4.41806599e+00]],
#
#        [[ 1.01169807e+00,  1.10783001e-02, -1.22812517e+01],
#         [-8.37036700e-03,  1.01053513e+00, -8.50818679e-01]],
#
#        [[ 1.00008793e+00,  2.84632361e-02, -1.24722460e+01],
#         [-7.98497582e-03,  9.86718787e-01,  6.93354062e+00]],
#
#        [[ 1.00539781e+00,  2.49401535e-02, -1.27436797e+01],
#         [-9.14208218e-03,  9.90375846e-01,  7.83100821e+00]],
#
#        [[ 9.95438134e-01,  1.51610901e-02, -6.07740305e+00],
#         [-3.23443255e-03,  9.87687543e-01,  6.62513625e+00]],
#
#        [[ 9.99770176e-01,  1.35262975e-02, -6.91886004e+00],
#         [-1.44680677e-03,  9.96724886e-01,  2.19483158e+00]],
#
#        [[ 9.99854960e-01,  7.80092547e-03, -4.31614707e+00],
#         [-2.50880307e-03,  1.00282174e+00, -1.35073998e+00]],
#
#        [[ 1.00060090e+00,  6.06331340e-04, -4.60907440e-01],
#         [-6.99282741e-04,  1.00193386e+00, -1.20393974e+00]],
#
#        [[ 9.99525868e-01,  1.75674641e-03, -1.34329659e+00],
#         [-1.76486226e-04,  1.00066193e+00,  1.27883508e-01]],
#
#        [[ 9.98507351e-01,  1.64727249e-05, -2.67745122e+00],
#         [-1.69238099e-04,  1.00062493e+00, -1.31867550e+00]],
#
#        [[ 9.98241830e-01,  1.28416500e-03,  1.50976874e+00],
#         [ 1.11149726e-04,  1.00314752e+00, -3.68565339e+00]],
#
#        [[ 9.96838348e-01, -1.27573502e-02,  7.50576000e+00],
#         [ 4.84958584e-03,  1.00594827e+00, -8.56134877e+00]],
#
#        [[ 9.98127523e-01, -3.79733583e-03,  3.65786458e+00],
#         [ 1.34551130e-03,  1.00461138e+00, -6.65370877e+00]],
#
#        [[ 9.99939283e-01,  4.42213518e-03, -1.32869794e+00],
#         [-1.85320145e-03,  9.94762353e-01,  3.87999233e+00]],
#
#        [[ 9.98345403e-01,  1.62439665e-03,  2.91949508e+00],
#         [-3.74923356e-03,  9.98947035e-01,  3.27672282e+00]],
#
#        [[ 1.00036528e+00, -3.69232580e-03,  2.39109014e+00],
#         [-2.21675080e-03,  1.00272626e+00, -2.41777485e+00]],
#
#        [[ 9.96802552e-01,  1.75855351e-03,  1.80433111e+00],
#         [-1.63145087e-03,  1.00093568e+00, -3.77144526e+00]],
#
#        [[ 9.99956913e-01, -5.80933600e-03,  4.21374656e+00],
#         [ 2.64596290e-04,  1.00542020e+00, -4.75529515e+00]],
#
#        [[ 9.97472340e-01, -8.78878468e-05,  1.88563724e+00],
#         [-1.60932209e-03,  9.99665126e-01, -1.01522987e+00]],
#
#        [[ 9.99122779e-01,  1.08650654e-03,  4.53362342e-02],
#         [-3.31697177e-03,  1.00292916e+00, -5.96725227e-01]],
#
#        [[ 9.99908583e-01,  4.28198621e-03,  3.13389268e-02],
#         [-4.00873987e-04,  1.00061779e+00, -6.86246518e-01]],
#
#        [[ 9.99103592e-01,  2.32572875e-03,  1.78162400e-01],
#         [-7.70705923e-04,  1.00216928e+00, -2.61044293e+00]],
#
#        [[ 9.99218772e-01,  3.71980397e-03, -1.64173857e+00],
#         [-3.51400806e-03,  1.00238547e+00, -3.12453686e+00]],
#
#        [[ 1.00076987e+00,  1.85080845e-03, -1.08662798e+00],
#         [-1.03458100e-03,  1.00154112e+00, -1.71546953e+00]],
#
#        [[ 9.99877851e-01, -2.58849383e-03,  2.44127989e+00],
#         [-1.34380190e-04,  1.00454591e+00, -2.54672674e+00]],
#
#        [[ 1.00103231e+00, -2.52420996e-03,  2.00572700e+00],
#         [ 1.79624146e-04,  1.00025805e+00, -1.34659205e-04]],
#
#        [[ 9.98697906e-01, -2.24109633e-03,  2.30966826e+00],
#         [-3.55809135e-04,  9.96791535e-01,  1.55071780e+00]],
#
#        [[ 1.00431586e+00, -7.52457654e-03,  3.41269244e+00],
#         [-4.07570926e-03,  1.00650650e+00, -3.25972069e+00]],
#
#        [[ 1.00174046e+00, -6.87097570e-03,  4.51575283e+00],
#         [-5.77589838e-03,  1.00713532e+00, -4.76062185e+00]],
#
#        [[ 1.00043363e+00, -1.31258840e-03,  1.72620236e+00],
#         [-2.21318422e-03,  9.99136378e-01,  4.15802240e-01]],
#
#        [[ 1.00308686e+00, -1.10232902e-03,  1.83447886e+00],
#         [-1.02112084e-03,  1.00023322e+00,  3.96902504e+00]],
#
#        [[ 1.00071564e+00, -7.43901931e-03,  4.04327999e+00],
#         [ 2.49484959e-03,  9.98434610e-01,  3.71591567e-01]],
#
#        [[ 9.97158305e-01,  1.86164984e-03,  4.29967856e-01],
#         [-5.08176732e-04,  9.96460973e-01,  7.46077526e-01]],
#
#        [[ 9.97800236e-01,  6.86800039e-03, -5.45168373e+00],
#         [-4.03580787e-03,  9.97900538e-01,  1.36461179e+00]],
#
#        [[ 9.99353258e-01,  3.01531993e-03, -1.03204916e+00],
#         [ 4.44847553e-04,  9.97729801e-01,  3.95252152e-01]],
#
#        [[ 9.97174475e-01, -4.28044558e-03,  2.60494151e+00],
#         [ 4.16041012e-03,  9.99159178e-01, -2.17784287e+00]],
#
#        [[ 9.97157337e-01,  2.65987756e-03, -1.11252864e+00],
#         [ 8.31203220e-05,  9.96395482e-01,  4.09968324e-01]],
#
#        [[ 1.00021316e+00,  2.49482368e-03, -6.67448162e-01],
#         [-1.17844109e-03,  9.99360969e-01,  1.56281785e-04]],
#
#        [[ 9.96225072e-01, -1.46346195e-02,  7.73799245e+00],
#         [ 2.12937180e-03,  9.97230186e-01, -3.14695566e-01]],
#
#        [[ 9.98812300e-01, -1.42162065e-02,  7.58510511e+00],
#         [ 2.57360835e-03,  1.00163700e+00, -2.59379831e+00]],
#
#        [[ 9.99714154e-01, -1.25841012e-02,  6.48775337e+00],
#         [-9.66553724e-04,  1.00468950e+00, -4.05202734e+00]],
#
#        [[ 9.98742409e-01, -5.40465143e-03,  3.75947397e+00],
#         [-3.88664860e-04,  9.99754793e-01, -9.28631286e-01]],
#
#        [[ 1.00166114e+00, -1.04209312e-02,  5.10317037e+00],
#         [ 2.14352939e-03,  1.00447427e+00, -3.70460844e+00]],
#
#        [[ 9.97305663e-01,  4.70984541e-03, -1.51127242e+00],
#         [-3.78512103e-03,  1.00042823e+00, -1.55736173e+00]],
#
#        [[ 1.00618128e+00,  1.07720205e-02, -7.77723917e+00],
#         [-4.64258024e-03,  1.01989870e+00, -1.36236559e+01]],
#
#        [[ 9.94521472e-01,  5.15020807e-03, -1.63881433e+00],
#         [-7.00349840e-03,  1.00240629e+00, -4.30792204e+00]],
#
#        [[ 9.96980571e-01,  6.14696059e-03, -1.30527340e+00],
#         [-6.78406214e-03,  1.00088133e+00, -1.37132791e-01]],
#
#        [[ 9.93590711e-01,  1.96108566e-02, -7.74510559e+00],
#         [-1.27219741e-02,  1.00787179e+00, -2.98865247e+00]],
#
#        [[ 9.91627597e-01,  1.05986882e-02, -6.39449792e+00],
#         [-6.63826087e-03,  1.00194624e+00, -2.21226762e+00]],
#
#        [[ 9.96436270e-01,  1.65328146e-02, -1.10958424e+01],
#         [-4.61421264e-03,  1.00631995e+00, -3.71995532e+00]],
#
#        [[ 1.00543189e+00,  1.54972847e-02, -9.09971563e+00],
#         [-1.48283082e-03,  1.01780527e+00, -1.19055379e+01]],
#
#        [[ 9.99276361e-01, -3.19365993e-04,  5.64078612e-02],
#         [-3.42633381e-03,  1.01631125e+00, -1.08062367e+01]],
#
#        [[ 9.96868027e-01,  1.42172510e-03, -4.96571119e-01],
#         [-8.82309678e-05,  1.00018327e+00, -2.10753143e+00]],
#
#        [[ 1.00067706e+00, -2.01766665e-03, -1.53975029e+00],
#         [-2.14328788e-04,  1.00069594e+00,  1.53303487e+00]],
#
#        [[ 9.99343105e-01,  1.14957924e-03, -1.32702826e+00],
#         [-2.84774200e-03,  1.00693209e+00, -3.58107767e+00]],
#
#        [[ 9.96094723e-01, -1.40544519e-04,  2.60183846e-01],
#         [ 1.67028301e-03,  9.99724872e-01, -5.44776936e+00]],
#
#        [[ 9.96743414e-01, -4.29823391e-03,  2.18222233e+00],
#         [ 1.10534076e-03,  1.00063766e+00, -3.64009478e+00]],
#
#        [[ 1.00565499e+00, -9.10194174e-03,  3.29056955e+00],
#         [ 1.53723654e-03,  1.00814812e+00, -5.03116754e+00]],
#
#        [[ 1.00799875e+00, -9.38266342e-03,  3.37012537e+00],
#         [ 2.46483665e-03,  1.00982282e+00, -5.02392717e+00]],
#
#        [[ 1.00580496e+00, -1.43512380e-02,  5.28521078e+00],
#         [ 1.39994019e-03,  1.01453698e+00, -9.13550947e+00]],
#
#        [[ 1.00104361e+00, -8.15374925e-03,  3.87861583e+00],
#         [ 2.91240726e-03,  1.00457000e+00, -4.71075088e+00]],
#
#        [[ 9.96340870e-01, -3.06627301e-02,  1.47564614e+01],
#         [ 6.13531499e-03,  9.91476662e-01, -1.43596422e-01]],
#
#        [[ 1.01300445e+00, -2.41757754e-02,  1.16404353e+01],
#         [ 4.92189498e-03,  1.00618530e+00, -4.98309489e+00]],
#
#        [[ 1.00395177e+00, -1.06713136e-02,  5.55811199e+00],
#         [ 1.11129626e-03,  1.00813703e+00, -6.89091263e+00]],
#
#        [[ 1.00127795e+00, -1.13080778e-02,  4.83979593e+00],
#         [ 3.20327482e-03,  1.00632035e+00, -5.45195359e+00]],
#
#        [[ 1.00055461e+00, -3.27161743e-03,  1.10599779e+00],
#         [ 2.33685071e-03,  9.99298698e-01, -3.98456112e-01]],
#
#        [[ 1.00221255e+00, -4.92064738e-03,  1.43994249e+00],
#         [ 1.96454127e-03,  1.00053661e+00, -5.31810668e-01]],
#
#        [[ 1.00336770e+00, -9.89992219e-03,  3.69193870e+00],
#         [ 1.61290660e-03,  1.00669814e+00, -5.71643945e+00]],
#
#        [[ 9.97859092e-01, -1.13435579e-02,  5.47392376e+00],
#         [ 4.03265609e-03,  1.00323998e+00, -5.01509598e+00]],
#
#        [[ 1.00303856e+00, -9.00492606e-03,  2.86876170e+00],
#         [ 9.34152694e-04,  1.01340388e+00, -7.70813601e+00]],
#
#        [[ 1.00671553e+00, -1.19946403e-02,  4.69580437e+00],
#         [ 3.81076744e-04,  1.02082149e+00, -1.32679424e+01]],
#
#        [[ 1.00637711e+00, -1.00217015e-02,  5.18938820e+00],
#         [ 1.07627508e-03,  1.01890496e+00, -1.65950934e+01]],
#
#        [[ 9.95316313e-01, -6.53523232e-03,  4.17390617e+00],
#         [-8.49359826e-04,  1.01097397e+00, -1.42357591e+01]],
#
#        [[ 9.99701725e-01, -7.38218070e-03,  3.34042016e+00],
#         [ 3.10001190e-03,  1.00011094e+00, -2.31505621e+00]],
#
#        [[ 1.00285562e+00, -6.99706854e-03,  5.81083355e+00],
#         [ 1.94330389e-03,  9.91221185e-01,  7.81721702e+00]],
#
#        [[ 9.89765768e-01, -1.15955553e-02,  1.13809764e+01],
#         [ 1.83954383e-03,  9.78705619e-01,  1.20945260e+01]],
#
#        [[ 9.99695057e-01, -5.48523052e-03,  4.38502474e+00],
#         [ 1.02591733e-03,  9.94737299e-01,  2.66048860e+00]],
#
#        [[ 9.92956475e-01, -3.99552375e-03,  5.48010506e+00],
#         [ 8.54300603e-04,  9.88374717e-01,  3.81863830e+00]],
#
#        [[ 9.96053094e-01, -5.04576759e-03,  6.05304334e+00],
#         [-1.92414647e-04,  9.82010418e-01,  1.16104936e+01]],
#
#        [[ 9.94154737e-01,  1.86327330e-03,  1.81317654e+00],
#         [-2.39110586e-03,  9.79646594e-01,  1.27336355e+01]],
#
#        [[ 9.98668790e-01, -5.38620549e-04,  1.12514426e+00],
#         [-9.57077331e-04,  9.93041245e-01,  4.75809349e+00]],
#
#        [[ 9.97516645e-01,  2.50034983e-03,  3.04483749e-01],
#         [-1.40036560e-03,  9.91010764e-01,  5.03781592e+00]]])

# %%
H_global =  np.zeros((len(fullImgPaths)-1, 3,3 ))

# %%
def getHGlobalRecursively(pos = 0, new_H = np.eye(3)):
  if pos == H_array.shape[0]:
    return 1
  if transformation == "Homography":
    new_H = np.matmul(new_H, H_array[pos] ) 
  elif transformation == "Affine":  
    new_H = np.matmul(new_H, np.vstack([H_array[pos], [0,0,1]]) )  
  
  H_global[pos] = new_H
  pos = pos+1;
  getHGlobalRecursively(pos,new_H)


getHGlobalRecursively()

# %%
# import shutil

# shutil.rmtree('globalRegistrationTransparent')

# %%
# !mkdir globalRegistrationTransparent

# %%
def globalImageRegistration(srcImg, destImg, index, imageName, padding=padding_size):
  ht, wd, cc= destImg.shape

  ww = wd + (2*padding)
  hh = ht + (2*padding)

  xx = (ww - wd) // 2
  yy = (hh - ht) // 2

  srcImg = cv2.bitwise_and(srcImg, srcImg, mask=mask_im)
  
  result = cv2.warpPerspective(srcImg, H_global[index], (ww, hh))

  return result

# %%
def getTransparentImg(src, imageName):
  tmp = cv2.cvtColor(src, cv2.COLOR_RGB2GRAY)
  _,alpha = cv2.threshold(tmp,0,255,cv2.THRESH_BINARY)
  r, g, b = cv2.split(src)
  rgba = [b,g,r, alpha]
  dst = cv2.merge(rgba,4)
  save_name = "/content/globalRegistrationTransparent/" + imageName
  cv2.imwrite(save_name, dst)

# %%
def globalRegistrationFirstImage(img, imageName, padding=padding_size):
  ht, wd, cc= img.shape

  ww = wd + (2*padding)
  hh = ht + (2*padding)

  color = (0,0,0)
  result = np.full((hh,ww,cc), color, dtype=np.uint8)

  xx = (ww - wd) // 2
  yy = (hh - ht) // 2

  # copy img image into center of result image
  
  img =cv2.bitwise_and(img, img, mask=mask_im)
  
  result[yy:yy+ht, xx:xx+wd] = img

  return result

# %%
# globalImageRegistration(srcImg, destImg, 7, "anon001_02320.png") 
# getTransparentImg("anon001_02320.png")

# %%
for i in range(len(fullImgPaths) - 1):
  destImgPath = fullImgPaths[0] #the first image
  srcImgPath =  fullImgPaths[i + 1];
  srcImg, destImg = inputAndVisualizeStitchPair(srcImgPath, destImgPath, False)
  if (i == 0):
    # add reference image which is the first image
    imageName = Path(fullImgPaths[i]).name
    src = globalRegistrationFirstImage(destImg, imageName)
    getTransparentImg(src, imageName)

  imageName = Path(fullImgPaths[i + 1]).name
  src = globalImageRegistration(srcImg, destImg, i, imageName)
  getTransparentImg(src, imageName)

# %%
# !zip -r /content/globalRegistration.zip /content/globalRegistrationTransparent
# Out:
# updating: content/globalRegistrationTransparent/ (stored 0%)
#   adding: content/globalRegistrationTransparent/anon010_02092.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02089.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02100.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02114.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02123.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02137.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02115.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02083.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02145.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02087.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02134.png (deflated 16%)
#   adding: content/globalRegistrationTransparent/anon010_02124.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02150.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02085.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02079.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02110.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02127.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02143.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02084.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02126.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02159.png (deflated 16%)
#   adding: content/globalRegistrationTransparent/anon010_02130.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02139.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02093.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02153.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02091.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02101.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02113.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02165.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02080.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02121.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02148.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02138.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02149.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02077.png (deflated 20%)
#   adding: content/globalRegistrationTransparent/anon010_02135.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02157.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02086.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02112.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02120.png (deflated 16%)
#   adding: content/globalRegistrationTransparent/anon010_02071.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02132.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02147.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02140.png (deflated 16%)
#   adding: content/globalRegistrationTransparent/anon010_02073.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02133.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02154.png (deflated 16%)
#   adding: content/globalRegistrationTransparent/anon010_02122.png (deflated 16%)
#   adding: content/globalRegistrationTransparent/anon010_02119.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02170.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02111.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02088.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02136.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02106.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02078.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02156.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02074.png (deflated 19%)
#   adding: content/globalRegistrationTransparent/anon010_02146.png (deflated 16%)
#   adding: content/globalRegistrationTransparent/anon010_02081.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02155.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02105.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02158.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02094.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02160.png (deflated 16%)
#   adding: content/globalRegistrationTransparent/anon010_02104.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02072.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02102.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02108.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02163.png (deflated 16%)
#   adding: content/globalRegistrationTransparent/anon010_02161.png (deflated 16%)
#   adding: content/globalRegistrationTransparent/anon010_02167.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02116.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02129.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02152.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02082.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02099.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02164.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02118.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02141.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02166.png (deflated 16%)
#   adding: content/globalRegistrationTransparent/anon010_02131.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02169.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02128.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02144.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02117.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02090.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02097.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02109.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02151.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02142.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02075.png (deflated 19%)
#   adding: content/globalRegistrationTransparent/anon010_02098.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02125.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02107.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02162.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02096.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02168.png (deflated 17%)
#   adding: content/globalRegistrationTransparent/anon010_02076.png (deflated 19%)
#   adding: content/globalRegistrationTransparent/anon010_02103.png (deflated 18%)
#   adding: content/globalRegistrationTransparent/anon010_02095.png (deflated 18%)
